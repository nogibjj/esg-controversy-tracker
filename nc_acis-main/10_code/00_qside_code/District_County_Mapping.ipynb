# %%
df['district_court']='1'

# %%
df.loc[df['key_county_num'] == '0', 'district_court'] = '15A'
df.loc[df['key_county_num'] == '10', 'district_court'] = '22A'
df.loc[df['key_county_num'] == '20', 'district_court'] = '23'
df.loc[df['key_county_num'] == '30', 'district_court'] = '16A'
df.loc[df['key_county_num'] == '40', 'district_court'] = '23'
df.loc[df['key_county_num'] == '50', 'district_court'] = '24'
df.loc[df['key_county_num'] == '60', 'district_court'] = '2'
df.loc[df['key_county_num'] == '70', 'district_court'] = '6'
df.loc[df['key_county_num'] == '80', 'district_court'] = '13'
df.loc[df['key_county_num'] == '90', 'district_court'] = '13'
df.loc[df['key_county_num'] == '100', 'district_court'] = '28'
df.loc[df['key_county_num'] == '110', 'district_court'] = '25'
df.loc[df['key_county_num'] == '120', 'district_court'] = '19A'
df.loc[df['key_county_num'] == '130', 'district_court'] = '25'
df.loc[df['key_county_num'] == '140', 'district_court'] = '1'
df.loc[df['key_county_num'] == '150', 'district_court'] = '3B'
df.loc[df['key_county_num'] == '160', 'district_court'] = '17A'
df.loc[df['key_county_num'] == '170', 'district_court'] = '25'
df.loc[df['key_county_num'] == '180', 'district_court'] = '15B'
df.loc[df['key_county_num'] == '190', 'district_court'] = '30'
df.loc[df['key_county_num'] == '200', 'district_court'] = '1'
df.loc[df['key_county_num'] == '210', 'district_court'] = '30'
df.loc[df['key_county_num'] == '220', 'district_court'] = '27B'
df.loc[df['key_county_num'] == '230', 'district_court'] = '13'
df.loc[df['key_county_num'] == '240', 'district_court'] = '3B'
df.loc[df['key_county_num'] == '250', 'district_court'] = '12'
df.loc[df['key_county_num'] == '260', 'district_court'] = '1'
df.loc[df['key_county_num'] == '270', 'district_court'] = '1'
df.loc[df['key_county_num'] == '280', 'district_court'] = '22B'
df.loc[df['key_county_num'] == '290', 'district_court'] = '22B'
df.loc[df['key_county_num'] == '300', 'district_court'] = '4'
df.loc[df['key_county_num'] == '310', 'district_court'] = '14'
df.loc[df['key_county_num'] == '320', 'district_court'] = '7'
df.loc[df['key_county_num'] == '330', 'district_court'] = '21'
df.loc[df['key_county_num'] == '340', 'district_court'] = '9'
df.loc[df['key_county_num'] == '350', 'district_court'] = '27A'
df.loc[df['key_county_num'] == '360', 'district_court'] = '1'
df.loc[df['key_county_num'] == '370', 'district_court'] = '30'
df.loc[df['key_county_num'] == '380', 'district_court'] = '9'
df.loc[df['key_county_num'] == '390', 'district_court'] = '8'
df.loc[df['key_county_num'] == '400', 'district_court'] = '18'
df.loc[df['key_county_num'] == '410', 'district_court'] = '6'
df.loc[df['key_county_num'] == '420', 'district_court'] = '11'
df.loc[df['key_county_num'] == '430', 'district_court'] = '30'
df.loc[df['key_county_num'] == '440', 'district_court'] = '29B'
df.loc[df['key_county_num'] == '450', 'district_court'] = '6'
df.loc[df['key_county_num'] == '460', 'district_court'] = '19D'
df.loc[df['key_county_num'] == '470', 'district_court'] = '2'
df.loc[df['key_county_num'] == '480', 'district_court'] = '22A'
df.loc[df['key_county_num'] == '490', 'district_court'] = '30'
df.loc[df['key_county_num'] == '500', 'district_court'] = '11'
df.loc[df['key_county_num'] == '510', 'district_court'] = '4'
df.loc[df['key_county_num'] == '520', 'district_court'] = '11'
df.loc[df['key_county_num'] == '530', 'district_court'] = '8'
df.loc[df['key_county_num'] == '540', 'district_court'] = '27B'
df.loc[df['key_county_num'] == '550', 'district_court'] = '30'
df.loc[df['key_county_num'] == '560', 'district_court'] = '24'
df.loc[df['key_county_num'] == '570', 'district_court'] = '2'
df.loc[df['key_county_num'] == '580', 'district_court'] = '29A'
df.loc[df['key_county_num'] == '590', 'district_court'] = '26'
df.loc[df['key_county_num'] == '600', 'district_court'] = '24'
df.loc[df['key_county_num'] == '610', 'district_court'] = '20A'
df.loc[df['key_county_num'] == '620', 'district_court'] = '19D'
df.loc[df['key_county_num'] == '630', 'district_court'] = '7'
df.loc[df['key_county_num'] == '640', 'district_court'] = '5'
df.loc[df['key_county_num'] == '650', 'district_court'] = '6'
df.loc[df['key_county_num'] == '660', 'district_court'] = '4'
df.loc[df['key_county_num'] == '670', 'district_court'] = '15B'
df.loc[df['key_county_num'] == '680', 'district_court'] = '3B'
df.loc[df['key_county_num'] == '690', 'district_court'] = '1'
df.loc[df['key_county_num'] == '700', 'district_court'] = '5'
df.loc[df['key_county_num'] == '710', 'district_court'] = '1'
df.loc[df['key_county_num'] == '720', 'district_court'] = '9'
df.loc[df['key_county_num'] == '730', 'district_court'] = '3A'
df.loc[df['key_county_num'] == '740', 'district_court'] = '29B'
df.loc[df['key_county_num'] == '750', 'district_court'] = '19B'
df.loc[df['key_county_num'] == '760', 'district_court'] = '16A'
df.loc[df['key_county_num'] == '770', 'district_court'] = '16B'
df.loc[df['key_county_num'] == '780', 'district_court'] = '17A'
df.loc[df['key_county_num'] == '790', 'district_court'] = '19C'
df.loc[df['key_county_num'] == '800', 'district_court'] = '29A'
df.loc[df['key_county_num'] == '810', 'district_court'] = '4'
df.loc[df['key_county_num'] == '820', 'district_court'] = '16A'
df.loc[df['key_county_num'] == '830', 'district_court'] = '20A'
df.loc[df['key_county_num'] == '840', 'district_court'] = '17B'
df.loc[df['key_county_num'] == '850', 'district_court'] = '17B'
df.loc[df['key_county_num'] == '860', 'district_court'] = '30'
df.loc[df['key_county_num'] == '870', 'district_court'] = '29B'
df.loc[df['key_county_num'] == '880', 'district_court'] = '2'
df.loc[df['key_county_num'] == '890', 'district_court'] = '20B 20C'
df.loc[df['key_county_num'] == '900', 'district_court'] = '9 9B'
df.loc[df['key_county_num'] == '910', 'district_court'] = '10'
df.loc[df['key_county_num'] == '920', 'district_court'] = '9B'
df.loc[df['key_county_num'] == '930', 'district_court'] = '2'
df.loc[df['key_county_num'] == '940', 'district_court'] = '24'
df.loc[df['key_county_num'] == '950', 'district_court'] = '8'
df.loc[df['key_county_num'] == '960', 'district_court'] = '23'
df.loc[df['key_county_num'] == '970', 'district_court'] = '7'
df.loc[df['key_county_num'] == '980', 'district_court'] = '23'
df.loc[df['key_county_num'] == '990', 'district_court'] = '24'
