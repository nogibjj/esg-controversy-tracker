# %% [markdown]
# # Prosecution severity
# ## Research questions:
# 1. Is there is a difference in severity of what the defendant is charged initially (by the police, I assume), that is, what's in *"charged_offense_code"*, compared with convitions, or the *"convicted_offense_code"*. we do this at the case level, so if an offense is dismissed by DA, it has zero severity.
# #### Other exploratory questions
# * I want to know whats the severity distribution of cases that get dropped vs. the ones that go to the judge
# * What is the best method to calculate severity?
# ### Data:
# 1. ACIS Cases
# 2. ACIS Offenses
# 3. NC Offense Codes with descriptions and classification
# 4. Sentencing Grid Class Ranks
# ### Steps:
# 1. (Done on separate script) Fix the NC Offense Codes dataset to capture codes that may have different classes in a separate column
# 2. Merge CHARGED and CONVICTED codes with the new NC Offense Codes to get classes and code descriptions
# 3. Marge CHARGED and CONVICTED offenses with the rank we make using the sentencing grid (just an ordering)
# 4. Once each offense has a "severity" associated, get the whole case deltas
# 5. Regression analiysis on AGGREGATES
# 6. Look at district court differences
# 7. Compare with system admissions (scatter plot)

# %%
import pandas as pd
import numpy as np

# I am blind without this
# %config InlineBackend.figure_format = 'retina' 

# see all columns
pd.set_option("max_columns", 200)


offenses = pd.read_csv(
    "/Users/clarissaache/Documents/Capstone/case_offense_v01.csv", #/Users/clarissaache/Documents/Capstone/case_offense_v01.csv
    low_memory=False,
    index_col=[0],
)

offense_desc_final = pd.read_csv('/Users/clarissaache/Documents/Capstone/JUSTFAIR_capstone/00_raw_data/ACIS_offence_codes_FIXED.csv')

# subset
offs = offenses[
    [
        "case_id",
        "date_of_birth",
        "key_county_num",
        "key_year",
        "court_type",
        "race",
        "sex",
        "process_served",
        "case_creation_date",
        "case_trial_date",
        "court_attorney_type",
        "bond_type",
        "bond_amount",
        "charged_offense_date",
        "charged_offense_code",
        "offense_class",
        # "Offense Description",
        # "CL",
        #'T',
        "min_sentence",
        "convicted_offense_code",
        "disposition",
        "disposition_date",
    ]
]

offs["charge_count"] = 1


offs.sample(5)
# Out:
# /var/folders/wj/g21k_l5x5l95gccmpm_gvn0c0000gn/T/ipykernel_97812/2922283137.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   offs["charge_count"] = 1
#                 case_id                                      date_of_birth  \
# 13465278  5902016239033  d8ca2cc758390d1b9ab550d2314e5c28ac3316bfa02a4f...
# 9482443   4002020080694  dcfc5a7951a4228f243d98b289becae92333e09aeb44f6...
# 7068908   3302016740001  16d960762c99714a308c2fa468551de72751f3b44d03bd...
# 21144103  9102015719130  eb44125085f081cf89e32e526e591fb7ae823210d8ae80...
# 5131066   2802013001927  43334badfd18c2325a2d5fec63a5de8e9c5ae85fa81fa1...
#
#           key_county_num  key_year court_type race sex process_served  \
# 13465278             590        16        CRS    B   M              M
# 9482443              400        20         CR    B   M              W
# 7068908              330        16         CR    O   M              C
# 21144103             910        15         CR    W   M              C
# 5131066              280        13         CR    W   M              C
#
#          case_creation_date case_trial_date court_attorney_type bond_type  \
# 13465278         2016-10-17      2017-12-14                   A       SEC
# 9482443          2020-08-23      2021-02-05                   P       SEC
# 7068908          2016-11-28      2017-02-08                   W       NaN
# 21144103         2015-03-25      2015-04-22                   W       NaN
# 5131066          2013-07-01      2013-11-19                   R       NaN
#
#           bond_amount charged_offense_date  charged_offense_code  \
# 13465278       1500.0           2016-10-16                  3544
# 9482443        2500.0           2020-08-23                  1389
# 7068908           NaN           2016-11-27                  5464
# 21144103          NaN           2015-03-25                  5450
# 5131066           NaN           2013-06-23                  6383
#
#          offense_class  min_sentence  convicted_offense_code disposition  \
# 13465278           NaN           NaN                     NaN          WP
# 9482443            NaN           NaN                     NaN          VD
# 7068908            NaN           NaN                     NaN          VD
# 21144103           NaN           NaN                  4450.0          JU
# 5131066              3           NaN                  6383.0          JU
#
#          disposition_date  charge_count
# 13465278       2016-12-09             1
# 9482443        2021-02-05             1
# 7068908        2017-02-08             1
# 21144103       2015-04-22             1
# 5131066        2013-11-19             1

# %% [markdown]
# ## Merge CHARGED and CONVICTED codes with Code Descriptions

# %%
# Merge with offence code CHARGED descriptions:
#offs_CHAR = offs.loc[~offs["convicted_offense_code"].isna()]


# rename cols
offense_desc_2 = offense_desc_final.rename(
    columns={
        "Offense Description": "charg_Off_Desc",
        "CODE": "charg_CODE",
        "T": "charg_type",
        "NC General Statute": "charg_statute",
        "CL_min": "charg_CL_min",
        "CL_Rank_min": "charg_CL_Rank_min",
        "CL_max": "charg_CL_max",
        "CL_Rank_max": "charg_CL_Rank_max",
    },
)


# merge
offs_rank = pd.merge(
    left=offs,
    right=offense_desc_2,
    left_on="charged_offense_code",
    right_on="charg_CODE",
    how="left",
    validate="m:m",
    indicator=True,
)
offs_rank._merge.value_counts()
# Out:
# both          23039363
# left_only           41
# right_only           0
# Name: _merge, dtype: int64

# %%
#offs_CONV = offs.loc[~offs["convicted_offense_code"].isna()]
offs_rank.drop(columns='_merge', inplace=True)
# ------------------------------------------------------------------------------------------------------------#

# Merge with offence code CONVICTED descriptions:
# rename cols
offense_desc_1 = offense_desc_final.rename(
    columns={
        "Offense Description": "conv_Off_Desc",
        "CODE": "conv_CODE",
        "T": "convc_type",
        "NC General Statute": "conv_statute",
        "CL_min": "conv_CL_min",
        "CL_Rank_min": "conv_CL_Rank_min",
        "CL_max": "conv_CL_max",
        "CL_Rank_max": "conv_CL_Rank_max",
    },
)

# make convictd off code int
#offs_CONV["convicted_offense_code"] = offs_CONV["convicted_offense_code"].astype(int)

# merge
offs_rank = pd.merge(
    left=offs_rank,
    right=offense_desc_1,
    left_on="convicted_offense_code",
    right_on="conv_CODE",
    how="left",
    validate="m:m",
    indicator=True,
)
offs_rank._merge.value_counts()
# Out:
# left_only     17408498
# both           5630906
# right_only           0
# Name: _merge, dtype: int64

# %%
offs_rank.sample(20)
offs_rank[
    [
        "case_id",
        "charged_offense_code",
        "convicted_offense_code",
        "charg_Off_Desc",
        "conv_Off_Desc",
        "offense_class",
        "charg_CL_min",
        "charg_CL_max",
        "conv_CL_min",
        "conv_CL_max",
        "process_served",
        "disposition",
    ]
].sample(20)
# Out:
#                 case_id  charged_offense_code  convicted_offense_code  \
# 27741        2009059252                  5032                     NaN
# 13903288  5902019213623                  2612                     NaN
# 17327222  7502019001661                  5038                     NaN
# 13222538  5902015023517                  5032                     NaN
# 21503349  9102017740553                  5441                     NaN
# 17087122  7502012712059                  5584                     NaN
# 88982        2013704164                  5450                  4450.0
# 17045541  7502004004547                  3470                     NaN
# 231651       2017707721                  5450                     NaN
# 15740366  6602018055731                  3415                     NaN
# 7182709   3302018050619                  5331                     NaN
# 1847087   1102017054337                  3401                     NaN
# 22888475  9702020000119                  5494                     NaN
# 18984192  8202018703545                  4721                     NaN
# 11130114  4902019051561                  3400                     NaN
# 20326904  9101990055515                  2606                     NaN
# 15187021  6402017005594                  5461                     NaN
# 11978395  5402013700835                  5494                     NaN
# 6116644   3102019053296                  2342                     NaN
# 13699747  5902018001115                  5494                     NaN
#
#                           charg_Off_Desc conv_Off_Desc offense_class  \
# 27741         FELONY PROBATION VIOLATION           NaN           NaN
# 13903288            FINANCIAL CARD THEFT           NaN           NaN
# 17327222    MISD PROB VIOL OUT OF COUNTY           NaN           NaN
# 13222538      FELONY PROBATION VIOLATION           NaN           NaN
# 21503349            NO OPERATORS LICENSE           NaN           NaN
# 17087122    HIT/RUN LEAVE SCENE PROP DAM           NaN           NaN
# 88982                           SPEEDING      SPEEDING           NaN
# 17045541     POSS MARIJ >1/2 TO 1 1/2 OZ           NaN           NaN
# 231651                          SPEEDING           NaN           NaN
# 15740366  CONSPIRE TRAFFIC METHAMPHETAMI           NaN           NaN
# 7182709        DISORDERLY CONDUCT-SCHOOL           NaN           NaN
# 1847087       POSSESS DRUG PARAPHERNALIA           NaN           NaN
# 22888475              OPERATE VEH NO INS           NaN           NaN
# 18984192     CANCL/REVOK/SUSP CERTIF/TAG           NaN           NaN
# 11130114     POSSESS MARIJ PARAPHERNALIA           NaN           NaN
# 20326904                 WORTHLESS CHECK           NaN           NaN
# 15187021   EXPIRED REGISTRATION CARD/TAG           NaN           NaN
# 11978395              OPERATE VEH NO INS           NaN           NaN
# 6116644    SHOPLIFTING CONCEALMENT GOODS           NaN           NaN
# 13699747              OPERATE VEH NO INS           NaN           NaN
#
#          charg_CL_min charg_CL_max conv_CL_min conv_CL_max process_served  \
# 27741              ??           ??         NaN         NaN              M
# 13903288            I            I         NaN         NaN              W
# 17327222           ??           ??         NaN         NaN              O
# 13222538           ??           ??         NaN         NaN              I
# 21503349            2            3         NaN         NaN              C
# 17087122            1            1         NaN         NaN              C
# 88982               2            3           0           0              C
# 17045541            1            1         NaN         NaN              C
# 231651              2            3         NaN         NaN              C
# 15740366           ??           ??         NaN         NaN              W
# 7182709             2            2         NaN         NaN              M
# 1847087             1            1         NaN         NaN              M
# 22888475            1            3         NaN         NaN              C
# 18984192            2            3         NaN         NaN              C
# 11130114            3            3         NaN         NaN              M
# 20326904           ??           ??         NaN         NaN              S
# 15187021            2            3         NaN         NaN              C
# 11978395            1            3         NaN         NaN              C
# 6116644            ??           ??         NaN         NaN              W
# 13699747            1            3         NaN         NaN              C
#
#          disposition
# 27741             PO
# 13903288          VD
# 17327222          PO
# 13222538          PO
# 21503349          VD
# 17087122          VD
# 88982             JU
# 17045541          VD
# 231651            VD
# 15740366          VD
# 7182709          NaN
# 1847087          NaN
# 22888475          VD
# 18984192          VD
# 11130114          VD
# 20326904          VD
# 15187021          VD
# 11978395          VD
# 6116644           VD
# 13699747          VD

# %%
offs_rank.loc[
    offs_rank["offense_class"].isna(), "charg_Off_Desc"
].value_counts()  # Looks like some traffic infractions like Speeding dont get a class
offs_rank.offense_class.value_counts(dropna=False)
# Out:
# NaN    20010840
# 3        940403
# 1        686991
# 2        519359
# H        246945
# 3.0      168291
# I        147324
# A1       116932
# G         53267
# F         40609
# 2.0       32084
# E         26281
# 1.0       22326
# D         12565
# C          8821
# B1         3784
# B2         1954
# A           625
# i             3
# Name: offense_class, dtype: int64

# %%
# lets fix the Offense Class column
offs_rank.loc[offs_rank["offense_class"] == "1.0", "offense_class"] = "1"
offs_rank.loc[offs_rank["offense_class"] == "2.0", "offense_class"] = "2"
offs_rank.loc[offs_rank["offense_class"] == "3.0", "offense_class"] = "3"
offs_rank.loc[offs_rank["offense_class"] == "i", "offense_class"] = "I"

# %%
# impute classes with mode for each offense code
mode_classes = pd.DataFrame(offs_rank.groupby('charged_offense_code')['offense_class'].agg(lambda x: pd.Series.mode(x))).reset_index()

mode_classes['offense_class'] = mode_classes['offense_class'].astype('str')
mode_classes.loc[mode_classes['offense_class'].str.contains("]"), 'offense_class']=np.nan

mode_classes.rename(columns={'offense_class':'offense_class_MODE'}, inplace=True)


offs_rank.drop(columns='_merge', inplace=True)
# merge
offs_rank = pd.merge(
    left=offs_rank,
    right=mode_classes,
    on='charged_offense_code',
    how="left",
    validate="m:m",
    indicator=True,
)

#offs_rank.rename(columns={'offense_class_x':'offense_class'}, inplace=True)
offs_rank['offense_class'].value_counts(dropna=False)
# Out:
# NaN    20010840
# 3       1108694
# 1        709317
# 2        551443
# H        246945
# I        147327
# A1       116932
# G         53267
# F         40609
# E         26281
# D         12565
# C          8821
# B1         3784
# B2         1954
# A           625
# Name: offense_class, dtype: int64

# %%
offs_rank.loc[offs_rank['offense_class']==" ", 'offense_class']=np.nan 
offs_rank.loc[offs_rank['offense_class']=="??", 'offense_class']=np.nan
offs_rank["offense_class"] = offs_rank["offense_class"].fillna(offs_rank["offense_class_MODE"])
# impute the rest with the statute class (I am going to use max, and I refuse to explain it to you)
offs_rank["offense_class"] = offs_rank["offense_class"].fillna(offs_rank["charg_CL_max"])
offs_rank['offense_class'].value_counts(dropna=False)
# Out:
# 3      11838824
# 1       3420871
# 2       2828398
# H       1529562
# I       1004164
# ??       809909
# A1       574340
# G        296291
# F        223587
# 0        157169
# E        150548
# D         77469
# C         61599
# B1        43568
# B2        22439
# A           625
# NaN          41
# Name: offense_class, dtype: int64

# %%
pd.crosstab(
    offs_rank.offense_class, offs_rank.charg_type, dropna=False
)  # may need to get rid of Infractions and all those "??"
# Out:
# charg_type                   F        I        M        T
# offense_class
# 0                   0        0   157169        0        0
# 1              104527   165652       98  2324339   826255
# 2               12325     7632   112035  1060284  1636122
# 3              237025     4933  1961047  1309652  8326167
# ??                 75   103283        0   290228   416323
# A                  10      609        0        4        2
# A1               7649    25900        1   538128     2662
# B1                401    43160        0        6        1
# B2               6759    15675        0        4        1
# C                 837    60739        0       21        2
# D                 441    77026        0        0        2
# E                2160   148374        0       11        3
# F                9882   213587        1       18       99
# G                3170   293117        0        4        0
# H               53071  1476013        0      160      318
# I               29612   974456        0       88        8

# %%
# how often is the "official offense class" not within the ranges of class given by statutes?
offs_rank[
    [
        "charged_offense_code",
        "charg_Off_Desc",
        "convc_type",
        "offense_class",
        "charg_CL_min",
        "charg_CL_max",
    ]
].sample(10)

offs_rank.loc[
    (offs_rank["offense_class"] != offs_rank["charg_CL_min"])
    & (offs_rank["offense_class"] != offs_rank["charg_CL_max"]),
    "charg_type",
].value_counts()

# SO, the offense class provided in the dataset is not accurate...

# % of offenses with missclassified offenses (by the court)
len(
    offs_rank.loc[
        (offs_rank["offense_class"] != offs_rank["charg_CL_min"])
        & (offs_rank["offense_class"] != offs_rank["charg_CL_max"]),
        "case_creation_date",
    ]
) * 100 / len(offs_rank.index)
# Out:
# 20.346771991150465

# %% [markdown]
# ## Severity #1: Class ranks:

# %%
# create ranks for classes
class_ranks = {
    "0": 0,
    "3": 1,
    "2": 2,
    "1": 3,
    "A1": 4,
    "I": 5,
    "H": 6,
    "G": 7,
    "F": 8,
    "E": 9,
    "D": 10,
    "C": 11,
    "B2": 12,
    "B1": 13,
    "A": 14,
    "??": np.nan,
}
class_ranks = pd.DataFrame.from_dict(class_ranks, "index").reset_index()
class_ranks.rename(columns={0: "CL_Rank"}, inplace=True)

#merge
offs_rank = pd.merge(offs_rank, class_ranks, left_on="offense_class", right_on="index", how="left")  # now, 'CL_rank' is the rank of the charged offense class provided by the court

# NOW lets look at deltas at the offense level for a second
offs_rank["delta_min"] = (offs_rank["conv_CL_Rank_min"] - offs_rank["CL_Rank"])  
#
# DELTA = final - initial, Delta MIN is the one using the minimum ranking of the convicted offense (when it can belong in two or more classes
# This means delta_min will be probably a larger delta than delta max
#
offs_rank["delta_max"] = offs_rank["conv_CL_Rank_max"] - offs_rank["CL_Rank"]

offs_rank.loc[offs_rank["conv_CL_min"] == "??", "charg_Off_Desc"].value_counts()
# Out:
# DRIVING WHILE IMPAIRED           296392
# INJURY TO PERSONAL PROPERTY       24773
# SHOPLIFTING CONCEALMENT GOODS     23189
# CRIMINAL CONTEMPT                 18234
# DANGEROUS DRUGS - FREE TEXT       14194
#                                   ...
# FAIL REPORT/TAG BIG GAME              1
# FORGERY OF DEEDS OR WILLS             1
# DWI - AGGRAVATED LEVEL 1              1
# INTERFERE WITH UTILITY METER          1
# ASSAULT HANDICAPPED PERSON            1
# Name: charg_Off_Desc, Length: 961, dtype: int64

# %%
# if codes are the same, fill NaN with 0
offs_rank.loc[
    offs_rank["charged_offense_code"] == offs_rank["convicted_offense_code"],
    "delta_min",
] = 0
offs_rank.loc[
    offs_rank["charged_offense_code"] == offs_rank["convicted_offense_code"],
    "delta_max",
] = 0

# %%
offs_rank.loc[
    offs_rank["charged_offense_code"] == offs_rank["convicted_offense_code"]
].sample(5)
# Out:
#                 case_id                                      date_of_birth  \
# 6678305   3302013061418  990fdd2ddcc66ec6431f91c613032e02fb620bd464f8a4...
# 18138672  7802016052637  de4f4c3cc781e3eaff8792ef0bcc9b66a1cf66f31bf3e5...
# 18322328  7902013707053  46ae08de9c00f8d2d03d1a02b6a4f32a77fee686b30740...
# 11751299  5202019705252  ed7aae9f5ab1cb9e6e31985d7540248058f89c111b40a1...
# 4016667   2402019701778  f1f09e45262baa9f6d11b369d0dc1520062c5c179d6fe4...
#
#           key_county_num  key_year court_type race sex process_served  \
# 6678305              330        13        CRS    B   M              M
# 18138672             780        16        CRS    W   F              W
# 18322328             790        13         CR    B   M              C
# 11751299             520        19         CR    W   M              C
# 4016667              240        19         CR    H   M              C
#
#          case_creation_date case_trial_date court_attorney_type bond_type  \
# 6678305          2013-11-20      2015-12-18                   A       SEC
# 18138672         2016-10-08      2017-08-01                   A       SEC
# 18322328         2013-09-07      2014-02-27                   R       NaN
# 11751299         2019-11-29      2020-01-09                   W       NaN
# 4016667          2019-03-03      2019-06-03                   R       NaN
#
#           bond_amount charged_offense_date  charged_offense_code  \
# 6678305        1000.0           2013-11-20                  5310
# 18138672      10000.0           2016-10-08                  3560
# 18322328          NaN           2013-09-07                  5450
# 11751299          NaN           2019-11-28                  3538
# 4016667           NaN           2019-03-02                  5441
#
#          offense_class  min_sentence  convicted_offense_code disposition  \
# 6678305              2           NaN                  5310.0          JU
# 18138672             I           6.0                  3560.0          JU
# 18322328             2           NaN                  5450.0          JU
# 11751299             1           6.0                  3538.0          JU
# 4016667              3           NaN                  5441.0          JU
#
#          disposition_date  charge_count  Unnamed: 0_x  charg_CODE  \
# 6678305        2015-12-14             1        1746.0      5310.0
# 18138672       2016-10-31             1         118.0      3560.0
# 18322328       2014-02-27             1        1300.0      5450.0
# 11751299       2020-01-09             1        1931.0      3538.0
# 4016667        2019-06-03             1        1298.0      5441.0
#
#                         charg_Off_Desc charg_type charg_statute charg_CL_min  \
# 6678305       RESISTING PUBLIC OFFICER          M        14-223            2
# 18138672  FELONY POSSESSION OF COCAINE          F   90-95(D)(2)            I
# 18322328                      SPEEDING          T    20-141(J1)            2
# 11751299  SIMPLE POSSESS SCH IV CS (M)          M   90-95(D)(2)            1
# 4016667           NO OPERATORS LICENSE          T       20-7(A)            2
#
#           charg_CL_Rank_min charg_CL_max  charg_CL_Rank_max  Unnamed: 0_y  \
# 6678305                 2.0            2                2.0        1746.0
# 18138672                5.0            I                5.0         118.0
# 18322328                2.0            3                1.0        1300.0
# 11751299                3.0            1                3.0        1931.0
# 4016667                 2.0            3                1.0        1298.0
#
#           conv_CODE                 conv_Off_Desc convc_type conv_statute  \
# 6678305      5310.0      RESISTING PUBLIC OFFICER          M       14-223
# 18138672     3560.0  FELONY POSSESSION OF COCAINE          F  90-95(D)(2)
# 18322328     5450.0                      SPEEDING          T   20-141(J1)
# 11751299     3538.0  SIMPLE POSSESS SCH IV CS (M)          M  90-95(D)(2)
# 4016667      5441.0          NO OPERATORS LICENSE          T      20-7(A)
#
#          conv_CL_min  conv_CL_Rank_min conv_CL_max  conv_CL_Rank_max  \
# 6678305            2               2.0           2               2.0
# 18138672           I               5.0           I               5.0
# 18322328           2               2.0           3               1.0
# 11751299           1               3.0           1               3.0
# 4016667            2               2.0           3               1.0
#
#          offense_class_MODE _merge index  CL_Rank  delta_min  delta_max
# 6678305                   2   both     2      2.0        0.0        0.0
# 18138672                  I   both     I      5.0        0.0        0.0
# 18322328                  3   both     2      2.0        0.0        0.0
# 11751299                  1   both     1      3.0        0.0        0.0
# 4016667                   3   both     3      1.0        0.0        0.0

# %%
offs_rank.loc[offs_rank['case_id']==7302019050100]
# Out:
#                 case_id                                      date_of_birth  \
# 16868180  7302019050100  689ad2efcf41896926166a3b34a38fc85a2f8086cfa68d...
#
#           key_county_num  key_year court_type race sex process_served  \
# 16868180             730        19         CR    B   M              M
#
#          case_creation_date case_trial_date court_attorney_type bond_type  \
# 16868180         2019-01-04      2019-07-23                   W       UNS
#
#           bond_amount charged_offense_date  charged_offense_code  \
# 16868180       1000.0           2019-01-04                  5709
#
#          offense_class  min_sentence  convicted_offense_code disposition  \
# 16868180             3           NaN                  5709.0          JU
#
#          disposition_date  charge_count  Unnamed: 0_x  charg_CODE  \
# 16868180       2019-07-23             1        1484.0      5709.0
#
#                   charg_Off_Desc charg_type charg_statute charg_CL_min  \
# 16868180  SECOND DEGREE TRESPASS          M     14-159.13            3
#
#           charg_CL_Rank_min charg_CL_max  charg_CL_Rank_max  Unnamed: 0_y  \
# 16868180                1.0            3                1.0        1484.0
#
#           conv_CODE           conv_Off_Desc convc_type conv_statute  \
# 16868180     5709.0  SECOND DEGREE TRESPASS          M    14-159.13
#
#          conv_CL_min  conv_CL_Rank_min conv_CL_max  conv_CL_Rank_max  \
# 16868180           3               1.0           3               1.0
#
#          offense_class_MODE _merge index  CL_Rank  delta_min  delta_max
# 16868180                  3   both     3      1.0        0.0        0.0

# %%
# looks like classes are roughly assigned to offenses

offs_rank[
    [
        "charged_offense_code",
        "charg_type",
        "charg_Off_Desc",
        "offense_class",
        "convc_type",
        "convicted_offense_code",
        "conv_Off_Desc",
        "conv_CL_min",
        "conv_CL_max",
        "CL_Rank",
        "conv_CL_Rank_min",
        "conv_CL_Rank_max",
        "delta_min",
        "delta_max",
    ]
].sample(15)
# there are still some NaN
# Out:
#           charged_offense_code charg_type                  charg_Off_Desc  \
# 8837505                   4716          T           DWLR NOT IMPAIRED REV
# 8076179                   5450          T                        SPEEDING
# 19674387                  9955          T    CIVIL REVOCATION DR LIC (30)
# 8209445                   5030          M      MISDEMEANOR PROBATION VIOL
# 3063163                   4726          T               DWLR IMPAIRED REV
# 4849481                   4725          T           DWLR NOT IMPAIRED REV
# 21061219                  3550          M  POSSESS MARIJUANA UP TO 1/2 OZ
# 22490007                  4725          T           DWLR NOT IMPAIRED REV
# 4434166                   1171          M  INTERFERE ELECT MONITOR DEV(M)
# 17042478                  5596          T             WINDOW TINTING VIOL
# 7015948                   4440          I           EXPIRED/NO INSPECTION
# 1215054                   1348          F                       AWDWIKISI
# 10880500                  3441          F                    SELL COCAINE
# 4128236                   3560          F    FELONY POSSESSION OF COCAINE
# 18200200                  3599                DANGEROUS DRUGS - FREE TEXT
#
#          offense_class convc_type  convicted_offense_code  \
# 8837505              3        NaN                     NaN
# 8076179              3          I                  4450.0
# 19674387            ??        NaN                     NaN
# 8209445              1        NaN                     NaN
# 3063163              1          T                  4726.0
# 4849481              3        NaN                     NaN
# 21061219             3        NaN                     NaN
# 22490007             3        NaN                     NaN
# 4434166              1        NaN                     NaN
# 17042478             3        NaN                     NaN
# 7015948              3        NaN                     NaN
# 1215054              E          F                  1346.0
# 10880500             G        NaN                     NaN
# 4128236              I        NaN                     NaN
# 18200200             I                             3599.0
#
#                         conv_Off_Desc conv_CL_min conv_CL_max  CL_Rank  \
# 8837505                           NaN         NaN         NaN      1.0
# 8076179                      SPEEDING           0           0      1.0
# 19674387                          NaN         NaN         NaN      NaN
# 8209445                           NaN         NaN         NaN      3.0
# 3063163             DWLR IMPAIRED REV           1           1      3.0
# 4849481                           NaN         NaN         NaN      1.0
# 21061219                          NaN         NaN         NaN      1.0
# 22490007                          NaN         NaN         NaN      1.0
# 4434166                           NaN         NaN         NaN      3.0
# 17042478                          NaN         NaN         NaN      1.0
# 7015948                           NaN         NaN         NaN      1.0
# 1215054           AWDW SERIOUS INJURY           E           E      9.0
# 10880500                          NaN         NaN         NaN      7.0
# 4128236                           NaN         NaN         NaN      5.0
# 18200200  DANGEROUS DRUGS - FREE TEXT          ??          ??      5.0
#
#           conv_CL_Rank_min  conv_CL_Rank_max  delta_min  delta_max
# 8837505                NaN               NaN        NaN        NaN
# 8076179                0.0               0.0       -1.0       -1.0
# 19674387               NaN               NaN        NaN        NaN
# 8209445                NaN               NaN        NaN        NaN
# 3063163                3.0               3.0        0.0        0.0
# 4849481                NaN               NaN        NaN        NaN
# 21061219               NaN               NaN        NaN        NaN
# 22490007               NaN               NaN        NaN        NaN
# 4434166                NaN               NaN        NaN        NaN
# 17042478               NaN               NaN        NaN        NaN
# 7015948                NaN               NaN        NaN        NaN
# 1215054                9.0               9.0        0.0        0.0
# 10880500               NaN               NaN        NaN        NaN
# 4128236                NaN               NaN        NaN        NaN
# 18200200               NaN               NaN        0.0        0.0

# %%
offs_rank["delta_min"].hist(bins=30)  # this is the most likely to be true
# Out:
# <AxesSubplot:>

# %%
# ok they look the same
offs_rank["delta_max"].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
# Clean up sex:
offs_rank.sex.value_counts()
offs_rank = offs_rank[offs_rank["sex"].isin(["M", "F", "U"])] # get rid of the X category, only 500 offenses 
offs_rank[["sex", "delta_max", "delta_min"]].groupby("sex").mean().reset_index()
# Out:
#   sex  delta_max  delta_min
# 0   F  -0.485766  -0.477855
# 1   M  -0.343270  -0.335814
# 2   U  -0.022152  -0.022679

# %% [markdown]
# # Aggregate results

# %%
# averages
offs_rank[["race", "delta_max", "delta_min"]].groupby(
    "race"
).mean().reset_index()  # whites are getting a drop in offense class that is higher than blacks and hispanics, asians see the highest drop
# Out:
#   race  delta_max  delta_min
# 0    A  -0.684631  -0.683998
# 1    B  -0.356658  -0.343860
# 2    H  -0.353413  -0.342576
# 3    I  -0.220915  -0.215090
# 4    O  -0.605199  -0.598263
# 5    U  -0.104833  -0.108508
# 6    W  -0.409828  -0.406411

# %%
# CONCLUSION 2

#offs_rank.loc[offs_rank["race"].isin(["I", "O", "U"]), "race"] = "Other"
offs_rank[["race", "delta_max", "delta_min"]].groupby("race").mean().reset_index()
# Out:
#   race  delta_max  delta_min
# 0    A  -0.684631  -0.683998
# 1    B  -0.356658  -0.343860
# 2    H  -0.353413  -0.342576
# 3    I  -0.220915  -0.215090
# 4    O  -0.605199  -0.598263
# 5    U  -0.104833  -0.108508
# 6    W  -0.409828  -0.406411

# %%
import statsmodels.formula.api as smf

# delta is the initial minus the final
m = smf.ols("delta_min ~ race + sex", offs_rank).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              delta_min   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                 1.804e+04
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:05:59   Log-Likelihood:            -4.1458e+06
# No. Observations:             5284079   AIC:                         8.292e+06
# Df Residuals:                 5284070   BIC:                         8.292e+06
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7800      0.003   -295.689      0.000      -0.785      -0.775
# race[T.B]      0.3384      0.003    127.949      0.000       0.333       0.344
# race[T.H]      0.3340      0.003    123.729      0.000       0.329       0.339
# race[T.I]      0.4695      0.003    142.272      0.000       0.463       0.476
# race[T.O]      0.0824      0.003     27.312      0.000       0.076       0.088
# race[T.U]      0.5555      0.005    119.629      0.000       0.546       0.565
# race[T.W]      0.2807      0.003    106.482      0.000       0.276       0.286
# sex[T.M]       0.1399      0.000    280.972      0.000       0.139       0.141
# sex[T.U]       0.2211      0.009     23.710      0.000       0.203       0.239
# ==============================================================================
# Omnibus:                   854088.126   Durbin-Watson:                   1.239
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1726247.679
# Skew:                          -0.986   Prob(JB):                         0.00
# Kurtosis:                       4.988   Cond. No.                         56.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Try Rank based on min sentence length

# %%
from sklearn.preprocessing import MinMaxScaler

# group by convicted offense and scale
p_ranks = (
    offenses[["convicted_offense_code", "min_sentence_day"]]
    .groupby("convicted_offense_code")
    .mean()
    .reset_index()
)
p_ranks["offense_rank"] = MinMaxScaler().fit_transform(
    np.array(p_ranks["min_sentence_day"]).reshape(-1, 1))

p_ranks = p_ranks.loc[~p_ranks['offense_rank'].isna()]

# %%
offense_desc_3 = offense_desc_final.rename(
    columns={
        "Offense Description": "Off_Desc",
        "CODE": "offense_code",
        "T": "type",
        "NC General Statute": "statute",
    },
)
offense_desc_3 = offense_desc_3.drop('Unnamed: 0', axis=1)
offense_desc_3.dtypes
# Out:
# offense_code      int64
# Off_Desc         object
# type             object
# statute          object
# CL_min           object
# CL_Rank_min     float64
# CL_max           object
# CL_Rank_max     float64
# dtype: object

# %%
# are the two ranking approaches different?
severity_comp = pd.merge(p_ranks, offense_desc_3, left_on='convicted_offense_code', right_on='offense_code',how='right', validate='m:m', indicator=True)
severity_comp._merge.value_counts()
# Out:
# both          1404
# right_only     707
# left_only        0
# Name: _merge, dtype: int64

# %%
severity_comp = severity_comp.loc[severity_comp['_merge']=="both"]
severity_comp = severity_comp.rename(
    columns={
        "Offense Description": "off_desc",
        "min_sentence":"min_sentence_Rank"
    },
)
severity_comp.sort_values(['offense_rank', 'CL_Rank_min'], ascending=False) # the ranks are different! rape and child-related stuff is worse in the min sentence driven scale. i get that
# Out:
#       convicted_offense_code  min_sentence_day  offense_rank  offense_code  \
# 605                   3633.0       9510.000000      1.000000          3633
# 638                   3635.0       9147.096774      0.961836          3635
# 641                   3641.0       8820.681818      0.927509          3641
# 626                   1104.0       8812.500000      0.926648          1104
# 639                   3636.0       8678.382353      0.912544          3636
# ...                      ...               ...           ...           ...
# 1133                  4483.0          1.000000      0.000000          4483
# 1147                  4497.0          1.000000      0.000000          4497
# 1193                  4551.0          1.000000      0.000000          4551
# 1194                  4552.0          1.000000      0.000000          4552
# 881                   6307.0          1.000000      0.000000          6307
#
#                             Off_Desc type          statute CL_min  \
# 605   INCEST CHILD 13/14/15 DEF> 4<6    F     14-178(B)(2)      C
# 638                  RAPE OF A CHILD    F      14-27.2A(A)     B1
# 641    STAT SEX OFF W/CHILD BY ADULT    F         14-27.28     B1
# 626       FIRST DEGREE FORCIBLE RAPE    F         14-27.21     B1
# 639      SEXUAL OFFENSE WITH A CHILD    F      14-27.4A(A)     B1
# ...                              ...  ...              ...    ...
# 1133                 ILLEGAL PARKING    I         20-162.1      0
# 1147   HANDICAPPED PARKING VIOLATION    I       20-37.6(E)      0
# 1193       ILLEGAL RIGHT TURN ON RED    I  20-158(B)(2)(A)      0
# 1194       IMPROPER PASSING ON RIGHT    I         20-150.1      0
# 881   EXCEED LIMIT OF FINFISH BY>50%    M        113-134.1     ??
#
#       CL_Rank_min CL_max  CL_Rank_max _merge
# 605          11.0      C         11.0   both
# 638          13.0     B1         13.0   both
# 641          13.0     B1         13.0   both
# 626          13.0     B1         13.0   both
# 639          13.0     B1         13.0   both
# ...           ...    ...          ...    ...
# 1133          0.0      0          0.0   both
# 1147          0.0      0          0.0   both
# 1193          0.0      0          0.0   both
# 1194          0.0      0          0.0   both
# 881           NaN     ??          NaN   both
#
# [1404 rows x 12 columns]

# %%
p_ranks
# Out:
#       convicted_offense_code  min_sentence_day  offense_rank
# 0                      910.0       4320.000000      0.454201
# 1                      916.0        480.000000      0.050373
# 2                      920.0       2090.046992      0.219692
# 3                      922.0        592.232645      0.062176
# 4                      930.0       3532.500000      0.371385
# ...                      ...               ...           ...
# 1709                  9974.0         26.260870      0.002657
# 1711                  9977.0         39.210526      0.004018
# 1712                  9978.0         28.224490      0.002863
# 1713                  9980.0        210.000000      0.021979
# 1715                  9999.0        394.684252      0.041401
#
# [1404 rows x 3 columns]

# %%
# merge with existing CONVICTED off code

offs_rank = offs_rank.drop("_merge", axis=1)
offs_rank2 = pd.merge(
    offs_rank,
    p_ranks[['convicted_offense_code', 'offense_rank']],
    how="left",
    on="convicted_offense_code",
    validate="m:m",
    indicator=True,
)
offs_rank2._merge.value_counts()
# Out:
# left_only     17329271
# both           5594175
# right_only           0
# Name: _merge, dtype: int64

# %%
# merge with existing CHARGED off code
offs_rank2.drop("_merge", axis=1, inplace=True)
p_ranks.rename(
    columns={
        "convicted_offense_code": "charged_offense_code",
        "offense_rank": "charged_offense_rank",
    },
    inplace=True,
)
offs_rank2 = pd.merge(
    offs_rank2,
    p_ranks[['charged_offense_code', 'charged_offense_rank']],
    how="left",
    on="charged_offense_code",
    validate="m:m",
    indicator=True,
)
offs_rank2._merge.value_counts()
# Out:
# both          22232428
# left_only       691018
# right_only           0
# Name: _merge, dtype: int64

# %%
offs_rank2.sample(5)
# Out:
#                 case_id                                      date_of_birth  \
# 14263276  6102016050253  18bcddd39d31860821d9c830d984c9ace5839b194df1fc...
# 18625611  8002018050273  3b8113a44c4bae562c2f642f5a2112dfe001520e0e16c9...
# 6104300   3102019052483  6c82189715621252b797794ea92325fb6b95d21df2340a...
# 1271638   1002006005527  e8a9c2d264a0dc543fb84cad1c0329b3a9d5f44799e111...
# 659397     602012001375  e7aa1956465b07ba356d21b456db239a21a49724519d0c...
#
#           key_county_num  key_year court_type race sex process_served  \
# 14263276             610        16        CRS    W   M              M
# 18625611             800        18        CRS    W   M              W
# 6104300              310        19        CRS    B   M              W
# 1271638              100         6         CR    H   M              C
# 659397                60        12         CR    W   F              C
#
#          case_creation_date case_trial_date court_attorney_type bond_type  \
# 14263276         2016-03-26      2016-08-31                   A       SEC
# 18625611         2018-01-29      2019-02-20                   A       NaN
# 6104300          2019-04-15      2020-02-03                   A       SEC
# 1271638          2006-04-06      2006-05-30                 NaN       NaN
# 659397           2012-11-07      2012-12-03                 NaN       NaN
#
#           bond_amount charged_offense_date  charged_offense_code  \
# 14263276          1.0           2016-03-25                  4430
# 18625611          NaN           2018-01-29                  2920
# 6104300        5000.0           2019-04-15                  2212
# 1271638           NaN           2006-03-19                  5494
# 659397            NaN           2012-10-31                  4470
#
#          offense_class  min_sentence  convicted_offense_code disposition  \
# 14263276             3           NaN                  4430.0          JU
# 18625611             1           NaN                  2920.0          JU
# 6104300              H           NaN                     NaN          SI
# 1271638              3           NaN                     NaN          VD
# 659397               3           NaN                  4470.0          WC
#
#          disposition_date  charge_count  Unnamed: 0_x  charg_CODE  \
# 14263276       2016-04-12             1        1080.0      4430.0
# 18625611       2018-05-08             1        1918.0      2920.0
# 6104300        2019-06-03             1         223.0      2212.0
# 1271638        2019-01-29             1        1259.0      5494.0
# 659397         2013-01-17             1        1120.0      4470.0
#
#                          charg_Off_Desc charg_type charg_statute charg_CL_min  \
# 14263276   MOTORCYCLE/MOPED HELMET/PSGR          I   20-140.4(A)            0
# 18625611        INJURY TO REAL PROPERTY          M        14-127            1
# 6104300    BREAKING AND OR ENTERING (F)          F      14-54(A)            H
# 1271638              OPERATE VEH NO INS          T     20-313(A)            1
# 659397    FAIL TO WEAR SEAT BELT-DRIVER          I     20-135.2A            0
#
#           charg_CL_Rank_min charg_CL_max  charg_CL_Rank_max  Unnamed: 0_y  \
# 14263276                0.0            0                0.0        1080.0
# 18625611                3.0            1                3.0        1918.0
# 6104300                 6.0            H                6.0           NaN
# 1271638                 3.0            3                1.0           NaN
# 659397                  0.0            0                0.0        1120.0
#
#           conv_CODE                  conv_Off_Desc convc_type conv_statute  \
# 14263276     4430.0   MOTORCYCLE/MOPED HELMET/PSGR          I  20-140.4(A)
# 18625611     2920.0        INJURY TO REAL PROPERTY          M       14-127
# 6104300         NaN                            NaN        NaN          NaN
# 1271638         NaN                            NaN        NaN          NaN
# 659397       4470.0  FAIL TO WEAR SEAT BELT-DRIVER          I    20-135.2A
#
#          conv_CL_min  conv_CL_Rank_min conv_CL_max  conv_CL_Rank_max  \
# 14263276           0               0.0           0               0.0
# 18625611           1               3.0           1               3.0
# 6104300          NaN               NaN         NaN               NaN
# 1271638          NaN               NaN         NaN               NaN
# 659397             0               0.0           0               0.0
#
#          offense_class_MODE index  CL_Rank  delta_min  delta_max  \
# 14263276                  3     3      1.0        0.0        0.0
# 18625611                  1     1      3.0        0.0        0.0
# 6104300                   H     H      6.0        NaN        NaN
# 1271638                   3     3      1.0        NaN        NaN
# 659397                    3     3      1.0        0.0        0.0
#
#           offense_rank  charged_offense_rank _merge
# 14263276      0.001157              0.001157   both
# 18625611      0.005709              0.005709   both
# 6104300            NaN              0.032156   both
# 1271638            NaN              0.003190   both
# 659397        0.002355              0.002355   both

# %%
# NOW lets look at the delta (again)!

offs_rank2.loc[
    offs_rank2["charged_offense_code"] == offs_rank2["convicted_offense_code"], "delta2"
] = 0


offs_rank2["delta2"] = offs_rank2["offense_rank"] -  offs_rank2["charged_offense_rank"] # convicted - charged

print(offs_rank2["delta2"].mean())

# pick a better name, better scale:
offs_rank2 = offs_rank2.rename(columns={'offense_rank':"conv_off_severity" ,'charged_offense_rank':'charg_off_severity'})


offs_rank2["delta2"].median()
# Out:
# -0.0017939187370494237
# 0.0

# %%
offs_rank2['conv_off_severity']=offs_rank2['conv_off_severity']*100
offs_rank2['charg_off_severity']=offs_rank2['charg_off_severity']*100

# %%
offs_rank2[["race", "delta_max", "delta_min", "delta2"]].groupby("race").mean().plot(kind='bar')
offs_rank2[["race","delta2"]].groupby("race").mean().plot(kind='bar')
# it is always negative, so the procecutors will negotiate a less severe sentence for you to plead guilty
offs_rank2[["race", "delta_max", "delta_min", "delta2"]].groupby("race").mean()
# i guess delta min and delta max are not that different...
# NEED TO LOOK AT RELATIVE DISTANCE
# Out:
#       delta_max  delta_min    delta2
# race
# A     -0.684631  -0.683998 -0.000856
# B     -0.356658  -0.343860 -0.002195
# H     -0.353413  -0.342576 -0.000872
# I     -0.220915  -0.215090 -0.001668
# O     -0.605199  -0.598263 -0.000636
# U     -0.104833  -0.108508 -0.003693
# W     -0.409828  -0.406411 -0.001790

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15, 8))
bins = 35

plt.hist(offs_rank2.loc[offs_rank2['race']=='B', 'delta_min'], bins, alpha=0.5, label='Black')
plt.hist(offs_rank2.loc[offs_rank2['race']=='W', 'delta_min'], bins, alpha=0.5, label='White')
plt.hist(offs_rank2.loc[offs_rank2['race']=='H', 'delta_min'], bins, alpha=0.5, label='Hispanic')
plt.hist(offs_rank2.loc[offs_rank2['race']=='A', 'delta_min'], bins, alpha=0.5, label='Asian')
plt.hist(offs_rank2.loc[offs_rank2['race']=='Other', 'delta_min'], bins, alpha=0.5, label='Other')
plt.legend(loc='upper right')

plt.show() #not very helpful

# %%
# trying different plots
bins = 5000
fig = plt.figure(figsize=(12, 6))

ax1 = plt.subplot(311)
plt.hist(offs_rank2.loc[offs_rank2['race']=='B', 'delta2'], bins, alpha=0.5, label='Black')
plt.legend(loc='upper right')

ax2 = plt.subplot(312, sharex=ax1)
plt.hist(offs_rank2.loc[offs_rank2['race']=='W', 'delta2'], bins, alpha=0.5, label='White')
plt.legend(loc='upper right')

ax3 = plt.subplot(313, sharex=ax1, sharey=ax1)
plt.hist(offs_rank2.loc[offs_rank2['race']=='H', 'delta2'], bins, alpha=0.5, label='Hispanic')


#plt.hist(offs_rank2.loc[offs_rank2['race']=='A', 'delta100'], bins, alpha=0.5, label='Asian')
#plt.hist(offs_rank2.loc[offs_rank2['race']=='Other', 'delta100'], bins, alpha=0.5, label='Other')

ax1.set_xlim(-.2,.2)

plt.legend(loc='upper right')
plt.show()

# %%
offs_rank2[
    [
        "charged_offense_code",
        "charg_type",
        "charg_Off_Desc",
        "offense_class",
        "convc_type",
        "convicted_offense_code",
        "conv_Off_Desc",
        "conv_CL_min",
        "conv_CL_max",
        "CL_Rank",
        "conv_CL_Rank_min",
        "conv_CL_Rank_max",
        "charg_off_severity",
        "conv_off_severity",
    ]
].sample(5)
# there are still some NaN
# Out:
#           charged_offense_code charg_type                  charg_Off_Desc  \
# 15405240                  5461          T   EXPIRED REGISTRATION CARD/TAG
# 19238774                  4721          T     CANCL/REVOK/SUSP CERTIF/TAG
# 15603163                  3550          M  POSSESS MARIJUANA UP TO 1/2 OZ
# 15468517                  2912          M     INJURY TO PERSONAL PROPERTY
# 7813261                   9918          F               FELONY CONSPIRACY
#
#          offense_class convc_type  convicted_offense_code  \
# 15405240             3        NaN                     NaN
# 19238774             3        NaN                     NaN
# 15603163             3          M                  3550.0
# 15468517             1        NaN                     NaN
# 7813261              I        NaN                     NaN
#
#                            conv_Off_Desc conv_CL_min conv_CL_max  CL_Rank  \
# 15405240                             NaN         NaN         NaN      1.0
# 19238774                             NaN         NaN         NaN      1.0
# 15603163  POSSESS MARIJUANA UP TO 1/2 OZ           3           3      1.0
# 15468517                             NaN         NaN         NaN      3.0
# 7813261                              NaN         NaN         NaN      5.0
#
#           conv_CL_Rank_min  conv_CL_Rank_max  charg_off_severity  \
# 15405240               NaN               NaN            0.183528
# 19238774               NaN               NaN            0.184947
# 15603163               1.0               1.0            0.152144
# 15468517               NaN               NaN            0.545959
# 7813261                NaN               NaN            4.145684
#
#           conv_off_severity
# 15405240                NaN
# 19238774                NaN
# 15603163           0.152144
# 15468517                NaN
# 7813261                 NaN

# %% [markdown]
# # Lets look at cases

# %%
convicted_off_ranks = offs_rank2[
    [
        "case_id",
        "date_of_birth",
        "charged_offense_code",
        "charg_type",
        #"charg_Off_Desc",
        "CL_Rank",
        #"convicted_offense_code",
        "conv_Off_Desc"	,
        "conv_CL_Rank_min",
        "conv_CL_Rank_max", 
        "charg_off_severity",
        "conv_off_severity",
    ]
]  # only cases that have convicted codes

cases_delta_code = pd.merge(
    offenses,
    convicted_off_ranks,
    how="left",
    on=["case_id", "date_of_birth", "charged_offense_code"],
    validate="m:m",
    indicator=True,
)
cases_delta_code._merge.value_counts()
# Out:
# both          27779508
# left_only       115958
# right_only           0
# Name: _merge, dtype: int64

# %%
pd.set_option("max_columns", 100)
cases_delta_code.sample(5)
# Out:
#                 case_id  key_county_num  key_county_num.1  key_century  \
# 5627289   2502017700560             250               250           20
# 4350407   2202019704752             220               220           20
# 10054400  3802018703114             380               380           20
# 24746951  9101996042361             910               910           19
# 24636826  9101989082667             910               910           19
#
#           key_year court_type  def_street_address def_city_address  \
# 5627289         17         CR     3505 BENNETT DR     FAYETTEVILLE
# 4350407         19         CR  13089 TIMBER COURT    PALOS HEIGHTS
# 10054400        18         CR   511B KINGSBURY ST           OXFORD
# 24746951        96         CR       114 BYRUM ST.             CARY
# 24636826        89         CR        RT 1 BOX 385           BENSON
#
#          def_state_address def_zip_address def_ext_zip_address  \
# 5627289                 NC           28301                 NaN
# 4350407                 IL           60463                 NaN
# 10054400                NC           27565                 NaN
# 24746951                NC           27511                 NaN
# 24636826                NC           27504                 NaN
#
#                                               date_of_birth race sex  \
# 5627289   9c667d644f56e846dd32b590605f2d4e76372982eba912...    B   M
# 4350407   eee02f95f211239bf0b4a7fcc5dcf53b3d90f8aefa7a3e...    B   M
# 10054400  ea562fd6964597be1a93d0765192f99ce525210deee460...    B   F
# 24746951                                                NaN    U   U
# 24636826  0a0b2475309eb876f91e964f8ed21ed0556e5407312d9e...    W   M
#
#          process_served case_creation_date process_service_date  \
# 5627289               C         2017-01-09           2017-01-09
# 4350407               C         2019-10-05           2019-10-05
# 10054400              C         2018-09-19           2018-09-18
# 24746951              S         1996-08-14                  NaN
# 24636826              C         1989-12-18           1989-12-04
#
#          case_trial_date court_attorney_type indictment_date bond_type  \
# 5627289       2017-02-24                 NaN             NaN       NaN
# 4350407       2020-01-17                   R             NaN       NaN
# 10054400      2018-11-01                 NaN             NaN       NaN
# 24746951             NaN                 NaN             NaN       NaN
# 24636826      1990-01-18                 NaN             NaN       NaN
#
#           bond_amount in_jail_indicator  jail_release_date  \
# 5627289           NaN               NaN                NaN
# 4350407           NaN               NaN                NaN
# 10054400          NaN               NaN                NaN
# 24746951          NaN               NaN                NaN
# 24636826          NaN               NaN                NaN
#
#           jail_commited_date arrest_date domestic_violence   race_gender  \
# 5627289                  NaN         NaN               NaN    Black Male
# 4350407                  NaN         NaN               NaN    Black Male
# 10054400                 NaN         NaN               NaN  Black Female
# 24746951                 NaN         NaN               NaN         Other
# 24636826                 NaN         NaN               NaN    White Male
#
#                             CRRKEY charged_offense_date  charged_offense_code  \
# 5627289   250201770056000201001100           2017-01-09                  4721
# 4350407   220201970475200402001100           2019-10-05                  5464
# 10054400  380201870311400201001100           2018-09-18                  5461
# 24746951  910199604236100201001100           1996-05-08                  2666
# 24636826  910198908266700201001100           1989-12-04                  5418
#
#          arraigned_offense_date  convicted_offense_code plea_code  \
# 5627289                     NaN                     NaN       NaN
# 4350407                     NaN                     NaN       NaN
# 10054400                    NaN                     NaN       NaN
# 24746951                    NaN                     NaN       NaN
# 24636826                    NaN                     NaN       NaN
#
#          verdict_code disposition disposition_date judge_code  min_sentence  \
# 5627289           NaN          VD       2017-03-09        NaN           NaN
# 4350407           NaN          VD       2020-01-17        NaN           NaN
# 10054400          NaN          VD       2018-11-01        NaN           NaN
# 24746951          NaN          VD       2013-03-22        NaN           NaN
# 24636826          NaN          VD       2019-06-25        NaN           NaN
#
#           max_sentence min_sentence_frame fines  restitution  probation_len  \
# 5627289            NaN                NaN   NaN          NaN            NaN
# 4350407            NaN                NaN   NaN          NaN            NaN
# 10054400           NaN                NaN   NaN          NaN            NaN
# 24746951           NaN                NaN   NaN          NaN            NaN
# 24636826           NaN                NaN   NaN          NaN            NaN
#
#          probation_frame supervised_probation_flag date to paid  \
# 5627289              NaN                       NaN          NaN
# 4350407              NaN                       NaN          NaN
# 10054400             NaN                       NaN          NaN
# 24746951             NaN                       NaN          NaN
# 24636826             NaN                       NaN          NaN
#
#          monies_paid_flag more_offense_check_flag max_sentence_frame  \
# 5627289               NaN                       Y                NaN
# 4350407               NaN                     NaN                NaN
# 10054400              NaN                     NaN                NaN
# 24746951              NaN                     NaN                NaN
# 24636826              NaN                       Y                NaN
#
#          domestic_violence_flag active_sentence_ind  community_service_hr  \
# 5627289                     NaN                 NaN                   NaN
# 4350407                     NaN                 NaN                   NaN
# 10054400                    NaN                 NaN                   NaN
# 24746951                      N                 NaN                   NaN
# 24636826                    NaN                 NaN                   NaN
#
#          offense_class  prior_record_points  judgement_file_number  \
# 5627289            NaN                  NaN                    NaN
# 4350407            NaN                  NaN                    NaN
# 10054400           NaN                  NaN                    NaN
# 24746951           NaN                  NaN                    NaN
# 24636826           NaN                  NaN                    NaN
#
#           judgement_file_offense_num court_cost  min_sentence_day  \
# 5627289                          NaN        NaN               NaN
# 4350407                          NaN        NaN               NaN
# 10054400                         NaN        NaN               NaN
# 24746951                         NaN        NaN               NaN
# 24636826                         NaN        NaN               NaN
#
#           max_sentence_day charg_type  CL_Rank conv_Off_Desc  \
# 5627289                NaN          T      1.0           NaN
# 4350407                NaN          T      2.0           NaN
# 10054400               NaN          T      1.0           NaN
# 24746951               NaN          M      2.0           NaN
# 24636826               NaN          T      3.0           NaN
#
#           conv_CL_Rank_min  conv_CL_Rank_max  charg_off_severity  \
# 5627289                NaN               NaN            0.184947
# 4350407                NaN               NaN            0.315677
# 10054400               NaN               NaN            0.183528
# 24746951               NaN               NaN            0.335544
# 24636826               NaN               NaN            0.695763
#
#           conv_off_severity _merge
# 5627289                 NaN   both
# 4350407                 NaN   both
# 10054400                NaN   both
# 24746951                NaN   both
# 24636826                NaN   both

# %%
# Class driven rank
cases_delta_code.loc[cases_delta_code["convicted_offense_code"].isna(), "conv_CL_Rank_max"] = 0
cases_delta_code.loc[cases_delta_code["convicted_offense_code"].isna(), "conv_CL_Rank_min"] = 0


#cases_delta_code.loc[cases_delta_code["CL_Rank"].isna(), "CL_Rank"] = 0 <----------THIS IS WRONG

# min sentence driven rank
cases_delta_code.loc[cases_delta_code["charged_offense_code"].isna(), "charg_off_severity"] = 0
cases_delta_code.loc[cases_delta_code["convicted_offense_code"].isna(), "conv_off_severity"] = 0

# %%
cases_delta_code.loc[cases_delta_code["case_id"] == 9701997010276][['conv_off_severity', 'charg_off_severity',"CL_Rank","conv_CL_Rank_min", 'disposition']]
#cases_delta_code.shape
# Out:
#           conv_off_severity  charg_off_severity  CL_Rank  conv_CL_Rank_min  \
# 27456740           0.000000           22.102014      8.0               0.0
# 27456741           0.000000           22.102014      8.0               0.0
# 27456742                NaN           22.102014      8.0               NaN
# 27456743           6.084765           22.102014      8.0               8.0
# 27456744           0.000000            2.379267      1.0               0.0
#
#          disposition
# 27456740          SI
# 27456741          SI
# 27456742          JU
# 27456743          JU
# 27456744          PO

# %%
cases_delta_code.CL_Rank.value_counts()
# Out:
# 1.0     12130026
# 3.0      4272143
# 2.0      3091537
# 6.0      2904904
# 5.0      1808261
# 4.0       712551
# 7.0       575535
# 8.0       543877
# 9.0       339082
# 0.0       162246
# 10.0      148631
# 13.0      102673
# 11.0       99669
# 12.0       43338
# 14.0        1077
# Name: CL_Rank, dtype: int64

# %%
CASEZ = (
    cases_delta_code[
        [
            "CL_Rank",
            "conv_CL_Rank_min",
            "conv_off_severity",
            "charg_off_severity",
            "case_id",
            #'prior_record_points'
        ]
    ]
    .groupby(by="case_id")
    .sum()
    .reset_index()
)
# relative change
CASEZ["case_DELTA_cl_perc"] = (CASEZ["conv_CL_Rank_min"] - CASEZ["CL_Rank"])*100/(CASEZ["CL_Rank"])
CASEZ["case_DELTA_ms_perc"] = (CASEZ["conv_off_severity"] - CASEZ["charg_off_severity"])*100/(CASEZ["charg_off_severity"])

# relative change (using average as denominator bc there are 0s)
CASEZ["case_DELTA_cl_rel"] = (CASEZ["conv_CL_Rank_min"] - CASEZ["CL_Rank"])/((CASEZ["CL_Rank"]+CASEZ["conv_CL_Rank_min"])/2)
CASEZ["case_DELTA_ms_rel"] = (CASEZ["conv_off_severity"] - CASEZ["charg_off_severity"])/((CASEZ["conv_off_severity"]+CASEZ["charg_off_severity"])/2)
CASEZ.loc[CASEZ.case_DELTA_cl_rel.isna()]

# fix the nas:
CASEZ.loc[(CASEZ['CL_Rank'] == 0) & (CASEZ['conv_CL_Rank_min']==0), 'case_DELTA_cl_rel']=0
CASEZ.loc[(CASEZ['conv_off_severity'] == 0) & (CASEZ['charg_off_severity']==0), 'case_DELTA_ms_rel']=0

# total change
CASEZ["case_DELTA_cl"] = CASEZ["conv_CL_Rank_min"] - CASEZ["CL_Rank"]
CASEZ["case_DELTA_ms"] = CASEZ["conv_off_severity"] - CASEZ["charg_off_severity"]

CASEZ.sample(20)
#BOOM
# Out:
#                 case_id  CL_Rank  conv_CL_Rank_min  conv_off_severity  \
# 5688531   4002020702126      1.0               0.0           0.000000
# 1998837   1802019700755      3.0               0.0           0.000000
# 4365647   3302019735592      1.0               0.0           0.000000
# 13935690  9702015701504      2.0               0.0           0.000000
# 6969911   5201991006783      1.0               0.0           0.000000
# 3888185   3302009021126      3.0               0.0           0.000000
# 5026054   4002003009203      1.0               0.0           0.000000
# 14034240  9802016700896      2.0               3.0           0.318967
# 7518592   5902001166943      2.0               0.0           0.000000
# 6000493   4202019704446      2.0               0.0           0.000000
# 11150136  7902012057227      7.0               3.0           0.695763
# 9334911   6402017053630      4.0               0.0           3.328451
# 3045326   2702021701961      1.0               0.0           0.316300
# 1624006   1502016050712      7.0               0.0           0.000000
# 410076     602014702248      3.0               2.0           0.247197
# 6909187   5002020000949      1.0               0.0           0.000000
# 315544     302018700700      2.0               0.0           0.000000
# 10949813  7702019704425      1.0               0.0           0.000000
# 669463     902017002344      4.0               0.0           0.000000
# 272160     302012000516     20.0               4.0           0.914197
#
#           charg_off_severity  case_DELTA_cl_perc  case_DELTA_ms_perc  \
# 5688531             0.255669         -100.000000         -100.000000
# 1998837             0.423587         -100.000000         -100.000000
# 4365647             0.183528         -100.000000         -100.000000
# 13935690            0.554459         -100.000000         -100.000000
# 6969911             0.377661         -100.000000         -100.000000
# 3888185             0.695763         -100.000000         -100.000000
# 5026054             0.247197         -100.000000         -100.000000
# 14034240            0.540863           50.000000          -41.026147
# 7518592             0.492080         -100.000000         -100.000000
# 6000493             0.405423         -100.000000         -100.000000
# 11150136            4.739194          -57.142857          -85.318951
# 9334911             4.984943         -100.000000          -33.229922
# 3045326             0.244883         -100.000000           29.163564
# 1624006             4.706846         -100.000000         -100.000000
# 410076              0.446160          -33.333333          -44.594490
# 6909187             0.152144         -100.000000         -100.000000
# 315544              0.405423         -100.000000         -100.000000
# 10949813            0.153705         -100.000000         -100.000000
# 669463              0.447290         -100.000000         -100.000000
# 272160             16.687575          -80.000000          -94.521691
#
#           case_DELTA_cl_rel  case_DELTA_ms_rel  case_DELTA_cl  case_DELTA_ms
# 5688531           -2.000000          -2.000000           -1.0      -0.255669
# 1998837           -2.000000          -2.000000           -3.0      -0.423587
# 4365647           -2.000000          -2.000000           -1.0      -0.183528
# 13935690          -2.000000          -2.000000           -2.0      -0.554459
# 6969911           -2.000000          -2.000000           -1.0      -0.377661
# 3888185           -2.000000          -2.000000           -3.0      -0.695763
# 5026054           -2.000000          -2.000000           -1.0      -0.247197
# 14034240           0.400000          -0.516137            1.0      -0.221895
# 7518592           -2.000000          -2.000000           -2.0      -0.492080
# 6000493           -2.000000          -2.000000           -2.0      -0.405423
# 11150136          -0.800000          -1.487935           -4.0      -4.043431
# 9334911           -2.000000          -0.398512           -4.0      -1.656493
# 3045326           -2.000000           0.254522           -1.0       0.071417
# 1624006           -2.000000          -2.000000           -7.0      -4.706846
# 410076            -0.400000          -0.573911           -1.0      -0.198963
# 6909187           -2.000000          -2.000000           -1.0      -0.152144
# 315544            -2.000000          -2.000000           -2.0      -0.405423
# 10949813          -2.000000          -2.000000           -1.0      -0.153705
# 669463            -2.000000          -2.000000           -4.0      -0.447290
# 272160            -1.333333          -1.792249          -16.0     -15.773378

# %%
CASEZ.loc[CASEZ["case_id"] == 9002014000957]
# Out:
#                 case_id  CL_Rank  conv_CL_Rank_min  conv_off_severity  \
# 12226664  9002014000957      2.0               0.0           0.169272
#
#           charg_off_severity  case_DELTA_cl_perc  case_DELTA_ms_perc  \
# 12226664            1.854207              -100.0          -90.870925
#
#           case_DELTA_cl_rel  case_DELTA_ms_rel  case_DELTA_cl  case_DELTA_ms
# 12226664               -2.0          -1.665384           -2.0      -1.684935

# %%
Empirical_Approach = CASEZ.case_DELTA_ms_rel
Class_Based_Approach = CASEZ.case_DELTA_cl_rel

plt.figure(figsize=(10,8))

plt.title('Frequency of Relative Change in Severity of Cases\n(using the Class-based Approach and Empirical Approach)')
plt.xlabel('Relative Change in Severity of Cases')
plt.ylabel('Frequency of Cases')

Empirical_Approach.hist(alpha=0.5, bins= 30,legend=True)
Class_Based_Approach.hist(alpha=0.5, bins= 30,legend=True)
# Out:
# <AxesSubplot:title={'center':'Frequency of Relative Change in Severity of Cases\n(using the Class-based Approach and Empirical Approach)'}, xlabel='Relative Change in Severity of Cases', ylabel='Frequency of Cases'>

# %%
cases_info = offenses[ #<------- HAS TO BE THE ORIGINAL DATASET bc offs has only convicted offenses
    [
        "case_id",
        "date_of_birth",
        "key_county_num",
        "key_year",
        "court_type",
        "race",
        "sex",
        "process_served",
        "case_creation_date",
        "court_attorney_type",
        "bond_type",
        "bond_amount",
        "charged_offense_code",
        "convicted_offense_code",
        "offense_class", #new
        "disposition",
        "court_cost",
        "prior_record_points",
        "judge_code",
        "plea_code",
        "verdict_code",
        "court_type",
        'def_zip_address',
    ]
]

cases_info.sample(2)
# Out:
#                 case_id                                      date_of_birth  \
# 18843444  8102018052984  f898a887e5527e8a21d1c14302d4d98c453cfd86954378...
# 1420536   1002014705952  d523e0eadfacbca10183174001304d5cca0e840b0c6680...
#
#           key_county_num  key_year court_type race sex process_served  \
# 18843444             810        18         CR    B   M              S
# 1420536              100        14         CR    W   M              C
#
#          case_creation_date court_attorney_type bond_type  bond_amount  \
# 18843444         2018-12-28                   W       SEC        500.0
# 1420536          2014-05-28                   P       NaN          NaN
#
#           charged_offense_code  convicted_offense_code offense_class  \
# 18843444                  6370                  6370.0             3
# 1420536                   5491                     NaN           NaN
#
#          disposition court_cost  prior_record_points judge_code plea_code  \
# 18843444          JU        NaN                  5.0        MCS        GU
# 1420536           VD        NaN                  NaN        NaN       NaN
#
#          verdict_code court_type def_zip_address
# 18843444           GU         CR           28328
# 1420536           NaN         CR           28804

# %%
len(cases_info.case_id.unique())
# Out:
# 14081546

# %%
cases_info.loc[~cases_info.plea_code.isna()].plea_code.value_counts(normalize=True, dropna=False)*100
# Out:
# GU    47.866144
# RL    34.255696
# GL     5.349246
# RS     4.978771
# NG     4.532285
# GA     1.627256
# NC     1.139484
# NR     0.221262
# OT     0.029856
# Name: plea_code, dtype: float64

# %%
cases_info.loc[cases_info["case_id"] == 9701997010276]
# Out:
#                 case_id                                      date_of_birth  \
# 22700100  9701997010276  bff266141526daf6bdce5356c965185b32f278f8c6fd54...
# 22700101  9701997010276  bff266141526daf6bdce5356c965185b32f278f8c6fd54...
# 22700102  9701997010276  bff266141526daf6bdce5356c965185b32f278f8c6fd54...
#
#           key_county_num  key_year court_type race sex process_served  \
# 22700100             970        97        CRS    W   F              W
# 22700101             970        97        CRS    W   F              W
# 22700102             970        97        CRS    W   F              W
#
#          case_creation_date court_attorney_type bond_type  bond_amount  \
# 22700100         1997-07-25                   A       NaN          NaN
# 22700101         1997-07-25                   A       NaN          NaN
# 22700102         1997-07-25                   A       NaN          NaN
#
#           charged_offense_code  convicted_offense_code offense_class  \
# 22700100                  1199                     NaN           NaN
# 22700101                  1199                  1118.0           NaN
# 22700102                  5099                     NaN           NaN
#
#          disposition court_cost  prior_record_points judge_code plea_code  \
# 22700100          SI        NaN                  NaN        NaN       NaN
# 22700101          JU      111.0                  NaN        GKB        GL
# 22700102          PO        NaN                  NaN        MFF       NaN
#
#          verdict_code court_type def_zip_address
# 22700100          NaN        CRS             NaN
# 22700101           GU        CRS             NaN
# 22700102          NaN        CRS             NaN

# %%
case_delta_analysis = pd.merge(
    cases_info, CASEZ, how="left", on="case_id", validate="m:m", indicator=True
)
case_delta_analysis._merge.value_counts()
# Out:
# both          23039404
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
case_delta_analysis.loc[case_delta_analysis["case_id"] == 9701997010276]
# Out:
#                 case_id                                      date_of_birth  \
# 22700100  9701997010276  bff266141526daf6bdce5356c965185b32f278f8c6fd54...
# 22700101  9701997010276  bff266141526daf6bdce5356c965185b32f278f8c6fd54...
# 22700102  9701997010276  bff266141526daf6bdce5356c965185b32f278f8c6fd54...
#
#           key_county_num  key_year court_type race sex process_served  \
# 22700100             970        97        CRS    W   F              W
# 22700101             970        97        CRS    W   F              W
# 22700102             970        97        CRS    W   F              W
#
#          case_creation_date court_attorney_type bond_type  bond_amount  \
# 22700100         1997-07-25                   A       NaN          NaN
# 22700101         1997-07-25                   A       NaN          NaN
# 22700102         1997-07-25                   A       NaN          NaN
#
#           charged_offense_code  convicted_offense_code offense_class  \
# 22700100                  1199                     NaN           NaN
# 22700101                  1199                  1118.0           NaN
# 22700102                  5099                     NaN           NaN
#
#          disposition court_cost  prior_record_points judge_code plea_code  \
# 22700100          SI        NaN                  NaN        NaN       NaN
# 22700101          JU      111.0                  NaN        GKB        GL
# 22700102          PO        NaN                  NaN        MFF       NaN
#
#          verdict_code court_type def_zip_address  CL_Rank  conv_CL_Rank_min  \
# 22700100          NaN        CRS             NaN     33.0               8.0
# 22700101           GU        CRS             NaN     33.0               8.0
# 22700102          NaN        CRS             NaN     33.0               8.0
#
#           conv_off_severity  charg_off_severity  case_DELTA_cl_perc  \
# 22700100           6.084765           90.787324          -75.757576
# 22700101           6.084765           90.787324          -75.757576
# 22700102           6.084765           90.787324          -75.757576
#
#           case_DELTA_ms_perc  case_DELTA_cl_rel  case_DELTA_ms_rel  \
# 22700100          -93.297781          -1.219512          -1.748751
# 22700101          -93.297781          -1.219512          -1.748751
# 22700102          -93.297781          -1.219512          -1.748751
#
#           case_DELTA_cl  case_DELTA_ms _merge
# 22700100          -25.0     -84.702559   both
# 22700101          -25.0     -84.702559   both
# 22700102          -25.0     -84.702559   both

# %% [markdown]
# # Regressions data

# %%
#only need the first 
case_delta_analysis.sort_values(['case_id', 'prior_record_points'], ascending=False)
regression = (
    case_delta_analysis[
        [
            "case_id",
            "CL_Rank",
            "case_DELTA_cl",
            "case_DELTA_ms",
            "case_DELTA_cl_perc",
            "case_DELTA_ms_perc",
            "case_DELTA_cl_rel",
            "case_DELTA_ms_rel",
            "key_county_num",
            "key_year",
            "race",
            "sex",
            #"charg_type",
            "court_attorney_type",
            "process_served",
            "prior_record_points",
            "plea_code",
            'def_zip_address',
        ]
    ]
    .groupby("case_id")
    .head(1)
    .reset_index(drop=True)
)

print(regression.shape)


#fix race
regression.loc[~regression['race'].isin(['W', 'B', 'H', 'A']), 'race']= "Other"
#regression = regression.loc[regression['race'].isin(['W', 'B', 'H'])] #proof of concept
regression.loc[regression['race']=='W', 'race']= 'White'
regression.loc[regression['race']=='B', 'race']= 'Black'
regression.loc[regression['race']=='H', 'race']= 'Hispanic'
regression.loc[regression['race']=='A', 'race']= 'Asian'

#fix year
#regression = regression.loc[regression['key_year']<=21]


# Fix gender
#regression = regression.loc[regression['sex'].isin(['F', 'M'])]
regression.loc[~regression['sex'].isin(["M", "F"]), 'sex']= "Other"
regression.loc[regression['sex']=='M', 'sex']= 'Male'
regression.loc[regression['sex']=='F', 'sex']= 'Female'

# fix attorney type
regression.loc[regression['court_attorney_type']=='a', 'court_attorney_type']='A'
regression.loc[regression['court_attorney_type']=='r', 'court_attorney_type']='R'
regression.loc[regression['court_attorney_type']=='p', 'court_attorney_type']='P'
regression.loc[regression['court_attorney_type']=='w', 'court_attorney_type']='W'
regression = regression.loc[regression['court_attorney_type'].isin(['A', 'P', 'R', 'W'])]
regression.loc[regression['court_attorney_type']=='A', 'court_attorney_type']='Appointed ($ hourly)'
regression.loc[regression['court_attorney_type']=='R', 'court_attorney_type']='Public Defender ($ salaried)'
regression.loc[regression['court_attorney_type']=='P', 'court_attorney_type']='Privately Retained Attorney or Self'
regression.loc[regression['court_attorney_type']=='W', 'court_attorney_type']='Waived Attorney'

#fix county number
regression['key_county_num'] = regression['key_county_num'].astype('str')

print(regression.shape)
regression.loc[regression["case_id"] == 9002014000957]
# Out:
# (14081546, 17)
# (8067356, 17)
#                 case_id  CL_Rank  case_DELTA_cl  case_DELTA_ms  \
# 12226664  9002014000957      2.0           -2.0      -1.684935
#
#           case_DELTA_cl_perc  case_DELTA_ms_perc  case_DELTA_cl_rel  \
# 12226664              -100.0          -90.870925               -2.0
#
#           case_DELTA_ms_rel key_county_num  key_year   race     sex  \
# 12226664          -1.665384            900        14  Black  Female
#
#            court_attorney_type process_served  prior_record_points plea_code  \
# 12226664  Appointed ($ hourly)              C                  1.0        GL
#
#          def_zip_address
# 12226664           27536

# %% [markdown]
# Type of Process Served on the Defendant
# - B - Bill of Information
# - C - Citation
# - I - Indictment
# - M - Magistrate Order
# - O - Other
# - S - Criminal Summons
# - W - Warrant
# - X - Statement of Charges

# %%
pd.crosstab(regression.race, regression.process_served, dropna=False, normalize='index')*100
# should I include this?
# Out:
# process_served         B          C         I          M         O         S  \
# race
# Asian           0.012550  74.876590  0.000000  14.526857  0.568942  1.165077
# Black           0.056852  50.986702  0.015239  20.864240  1.161601  2.993559
# Hispanic        0.021254  80.622701  0.006632  12.149533  0.171541  0.695207
# Other           0.031448  59.053252  0.014612  13.537630  2.103531  6.102210
# White           0.092738  55.245165  0.018778  19.189835  1.428057  3.142278
#
# process_served          W         X
# race
# Asian            8.655455  0.194528
# Black           23.524290  0.397519
# Hispanic         6.120892  0.212240
# Other           18.959416  0.197901
# White           20.605757  0.277392

# %%
# key year as datetime
regression['key_year']=regression['key_year'].astype('int')
regression.loc[(regression['key_year']<40)&(regression['key_year']>9), 'key_year']='20'+ regression['key_year'].astype('str')
regression['key_year']=regression['key_year'].astype('int')
regression.loc[(regression['key_year']<2000)&(regression['key_year']>9), 'key_year']='19'+ regression['key_year'].astype('str')
regression['key_year']=regression['key_year'].astype('int')
regression.loc[regression['key_year']<10, 'key_year']='200'+ regression['key_year'].astype('str')
regression['year'] = pd.to_datetime(regression['key_year'],format='%Y').dt.strftime('%Y') #, errors='coerce')

# %%
# how does it look across time? theres something wrong with this year variable
import matplotlib.pyplot as plt
plt.figure(figsize=(30,8))
plt.scatter(regression.year, regression.case_DELTA_cl_rel)


plt.show()

# %% [markdown]
# ### Add the county stuff

# %%
# import county demographic proportions and representations
admissions = pd.read_csv('/Users/clarissaache/Documents/Capstone/JUSTFAIR_capstone/admissions_analysis_table.csv')
zip_county_crosswalk = pd.read_excel('/Users/clarissaache/Documents/Capstone/JUSTFAIR_capstone/ZIP_COUNTY.xlsx')

admissions.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)
admissions.sample(5)
zip_county_crosswalk = zip_county_crosswalk[['zip', 'county', 'usps_zip_pref_city', 'usps_zip_pref_state']]
#zip_county_crosswalk.rename(columns={'zip':'def_zip_address'}, inplace=True)
zip_county_crosswalk = zip_county_crosswalk.loc[zip_county_crosswalk['usps_zip_pref_state']=='NC']
#zip_county_crosswalk['zip'] = zip_county_crosswalk['zip'].astype('int')
zip_county_crosswalk['zip'] = zip_county_crosswalk['zip'].astype('str')

admissions['county_fips_code'] = admissions['county_fips_code'].astype('int') 

# merge ZIP with crosswalk to FIPS
regression_fips = pd.merge(regression,zip_county_crosswalk, how='left', left_on='def_zip_address', right_on='zip', indicator=True, validate='m:m')
regression_fips.drop('_merge', axis=1, inplace=True)

# merge with admissions data from preet
regression_admissions = pd.merge(regression_fips,admissions, how='left', left_on='county', right_on='county_fips_code', indicator=True, validate='m:m')
regression_admissions._merge.value_counts()

regression_admissions.sample(3)
regression_admissions.to_csv('/Users/clarissaache/Documents/Capstone/JUSTFAIR_capstone/30_gis/plea_deltas_admissions.csv')

regression_admissions.sample(3)
# Out:
#                case_id  CL_Rank  case_DELTA_cl  case_DELTA_ms  \
# 5464008  4002019073951     11.0          -11.0      -5.005152
# 8927946  6402015057260      2.0           -2.0      -1.928935
# 2738855  2502009062711     60.0          -51.0    -103.304584
#
#          case_DELTA_cl_perc  case_DELTA_ms_perc  case_DELTA_cl_rel  \
# 5464008              -100.0         -100.000000          -2.000000
# 8927946              -100.0          -77.608093          -2.000000
# 2738855               -85.0          -93.058526          -1.478261
#
#          case_DELTA_ms_rel key_county_num key_year   race   sex  \
# 5464008          -2.000000            400     2019  Black  Male
# 8927946          -1.268190            640     2015  Other  Male
# 2738855          -1.740364            250     2009  Black  Male
#
#                          court_attorney_type process_served  \
# 5464008  Privately Retained Attorney or Self              W
# 8927946                      Waived Attorney              M
# 2738855         Public Defender ($ salaried)              W
#
#          prior_record_points plea_code def_zip_address  year    zip   county  \
# 5464008                  NaN       NaN           28081  2019  28081  37025.0
# 8927946                  NaN        GU           27403  2015  27403  37081.0
# 2738855                  NaN       NaN           28390  2009  28390  37051.0
#
#         usps_zip_pref_city usps_zip_pref_state  county_fips_code  \
# 5464008         KANNAPOLIS                  NC           37025.0
# 8927946         GREENSBORO                  NC           37081.0
# 2738855        SPRING LAKE                  NC           37051.0
#
#          black_count_sys  white_count_sys  hisp_count_sys  total_count_sys  \
# 5464008         333890.0         240450.0         82202.0         682896.0
# 8927946         454988.0         339967.0         64455.0         893979.0
# 2738855         330236.0         191829.0         39462.0         597679.0
#
#          black_perc_sys  white_perc_sys  hisp_perc_sys             COUNTY  \
# 5464008       48.893243       35.210339      12.037265    Cabarrus County
# 8927946       50.894708       38.028522       7.209901    Guilford County
# 2738855       55.253071       32.095657       6.602541  Cumberland County
#
#             total  black_pop  white_pop  hisp_pop  other_pop  total_perc  \
# 5464008  196716.0    33787.0   133776.0   19434.0     9719.0       100.0
# 8927946  517197.0   174443.0   265946.0   39488.0    37320.0       100.0
# 2738855  332766.0   121699.0   148550.0   37746.0    24771.0       100.0
#
#          black_pop_perc  white_pop_perc  hisp_pop_perc  other_pop_perc  \
# 5464008       17.175522       68.004636       9.879217        4.940625
# 8927946       33.728541       51.420639       7.635002        7.215819
# 2738855       36.571945       44.640979      11.343106        7.443970
#
#          white_rate_of_case  black_rate_of_case  \
# 5464008            1.797408            9.882203
# 8927946            1.278331            2.608233
# 2738855            1.291343            2.713547
#
#          times_b_more_likely_to_be_involved_in_case  trial_metric  \
# 5464008                                    5.498031      2.328918
# 8927946                                    2.040343      0.769393
# 2738855                                    2.101337      0.791832
#
#          weighted_rep_difference_b_w _merge
# 5464008                     2.328918   both
# 8927946                     0.769393   both
# 2738855                     0.791832   both

# %%
regression_admissions.sample(3)
# Out:
#                case_id  CL_Rank  case_DELTA_cl  case_DELTA_ms  \
# 5648218  4202007701737      2.0           -2.0      -0.540863
# 655971    902014702813      1.0            1.0       0.000000
# 1722846  1502013702747      2.0            0.0       0.000000
#
#          case_DELTA_cl_perc  case_DELTA_ms_perc  case_DELTA_cl_rel  \
# 5648218              -100.0              -100.0          -2.000000
# 655971                100.0                 0.0           0.666667
# 1722846                 0.0                 0.0           0.000000
#
#          case_DELTA_ms_rel key_county_num key_year   race   sex  \
# 5648218               -2.0            420     2007  White  Male
# 655971                 0.0             90     2014  White  Male
# 1722846                0.0            150     2013  White  Male
#
#                   court_attorney_type process_served  prior_record_points  \
# 5648218  Public Defender ($ salaried)              C                  NaN
# 655971                Waived Attorney              C                  0.0
# 1722846  Public Defender ($ salaried)              C                  0.0
#
#         plea_code def_zip_address  year    zip   county usps_zip_pref_city  \
# 5648218       NaN           28334  2007  28334  37085.0               DUNN
# 655971         GU           28425  2014  28425  37141.0             BURGAW
# 1722846        GU           28560  2013  28560  37137.0           NEW BERN
#
#         usps_zip_pref_state  county_fips_code  black_count_sys  \
# 5648218                  NC           37085.0         141424.0
# 655971                   NC           37141.0          64465.0
# 1722846                  NC           37137.0          21654.0
#
#          white_count_sys  hisp_count_sys  total_count_sys  black_perc_sys  \
# 5648218         194738.0         51500.0         405538.0       34.873181
# 655971           99577.0         14258.0         184573.0       34.926560
# 1722846          34026.0          2254.0          59835.0       36.189521
#
#          white_perc_sys  hisp_perc_sys          COUNTY     total  black_pop  \
# 5648218       48.019668      12.699180  Harnett County  128753.0    27243.0
# 655971        53.949928       7.724857   Pender County   57630.0     9028.0
# 1722846       56.866383       3.767026  Pamlico County   12803.0     2375.0
#
#          white_pop  hisp_pop  other_pop  total_perc  black_pop_perc  \
# 5648218    79933.0   16210.0     5367.0       100.0       21.159119
# 655971     42945.0    4057.0     1600.0       100.0       15.665452
# 1722846     9508.0     456.0      464.0       100.0       18.550340
#
#          white_pop_perc  hisp_pop_perc  other_pop_perc  white_rate_of_case  \
# 5648218       62.082437      12.589998        4.168447            2.436265
# 655971        74.518480       7.039736        2.776332            2.318710
# 1722846       74.263844       3.561665        3.624151            3.578671
#
#          black_rate_of_case  times_b_more_likely_to_be_involved_in_case  \
# 5648218            5.191205                                    2.130804
# 655971             7.140563                                    3.079541
# 1722846            9.117474                                    2.547726
#
#          trial_metric  weighted_rep_difference_b_w _merge
# 5648218      0.874657                     0.874657   both
# 655971       1.505547                     1.505547   both
# 1722846      1.185147                     1.185147   both

# %%
regression = regression_admissions[[
            "case_id",
            "CL_Rank",
            "case_DELTA_cl",
            "case_DELTA_ms",
            "case_DELTA_cl_perc",
            "case_DELTA_ms_perc",
            "case_DELTA_cl_rel",
            "case_DELTA_ms_rel",
            "key_county_num",
            "key_year",
            "race",
            "sex",
            #"charg_type",
            "court_attorney_type",
            "process_served",
            "prior_record_points",
            "plea_code",
            'def_zip_address',
            'usps_zip_pref_city',
            'year',
            'COUNTY',
            'total',
]].sort_values(['case_id','total'], ascending=False).drop_duplicates(subset = 'case_id', keep='first')
print(regression.shape)
# Out:
# (8067356, 21)

# %%
regression.sample(4)
# Out:
#                 case_id  CL_Rank  case_DELTA_cl  case_DELTA_ms  \
# 4887683   4002012074136     15.0          -12.0     -14.897854
# 4089968   3302015732327      1.0           -1.0      -0.183528
# 6054125   4402017704537      2.0            2.0       0.000000
# 10416617  7702012709565      2.0           -2.0      -0.715806
#
#           case_DELTA_cl_perc  case_DELTA_ms_perc  case_DELTA_cl_rel  \
# 4887683                -80.0          -96.352954          -1.333333
# 4089968               -100.0         -100.000000          -2.000000
# 6054125                100.0            0.000000           0.666667
# 10416617              -100.0         -100.000000          -2.000000
#
#           case_DELTA_ms_rel key_county_num key_year      race     sex  \
# 4887683           -1.859251            400     2012     Black    Male
# 4089968           -2.000000            330     2015     White  Female
# 6054125            0.000000            440     2017  Hispanic    Male
# 10416617          -2.000000            770     2012  Hispanic    Male
#
#                    court_attorney_type process_served  prior_record_points  \
# 4887683                Waived Attorney              W                  5.0
# 4089968                Waived Attorney              C                  NaN
# 6054125   Public Defender ($ salaried)              C                  0.0
# 10416617  Public Defender ($ salaried)              C                  NaN
#
#          plea_code def_zip_address usps_zip_pref_city  year            COUNTY  \
# 4887683         GU           27407         GREENSBORO  2012   Guilford County
# 4089968        NaN           27052        WALNUT COVE  2015    Forsyth County
# 6054125         GU           28731          FLAT ROCK  2017  Henderson County
# 10416617       NaN           28376            RAEFORD  2012       Hoke County
#
#              total
# 4887683   517197.0
# 4089968   368362.0
# 6054125   112156.0
# 10416617   52571.0

# %% [markdown]
# District Court Attorney Type Code<br>
# * A - Appointed
# * P - Public Defender
# * R - Privately Retained or Self
# * W - Waived

# %% [markdown]
# ## Regression # 1: **Capstone Presentation**

# %%
import statsmodels.formula.api as smf
######################## THIS IS WHAT WENT IN THE PRESENTATION #############################

# Using the Class Rank severity scale
m_RANK = smf.ols("case_DELTA_cl ~ race + sex + prior_record_points + court_attorney_type", regression).fit() 
colors = ['r' if m > 0 else 'g' for m in m_RANK.params]

# plot effects
m_RANK.params.plot(kind='bar', title= "Who gets better plea deals?", figsize=(15,8),color=colors,legend=False, ylabel='Delta Case Offenses Class Rank')  
plt.tight_layout()
plt.savefig('Who_gets_better_deals.png', transparent=True)
m_RANK.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          case_DELTA_cl   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                 1.163e+04
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:31:54   Log-Likelihood:            -4.7150e+06
# No. Observations:             1518819   AIC:                         9.430e+06
# Df Residuals:                 1518808   BIC:                         9.430e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     -2.5677      0.066    -39.113      0.000      -2.696      -2.439
# race[T.Black]                                                 -0.3827      0.065     -5.908      0.000      -0.510      -0.256
# race[T.Hispanic]                                               0.4056      0.065      6.208      0.000       0.278       0.534
# race[T.Other]                                                  0.0250      0.068      0.367      0.713      -0.109       0.159
# race[T.White]                                                 -0.3244      0.065     -5.020      0.000      -0.451      -0.198
# sex[T.Male]                                                   -0.0993      0.010    -10.242      0.000      -0.118      -0.080
# sex[T.Other]                                                  -1.4195      0.153     -9.296      0.000      -1.719      -1.120
# court_attorney_type[T.Privately Retained Attorney or Self]     0.2733      0.018     15.307      0.000       0.238       0.308
# court_attorney_type[T.Public Defender ($ salaried)]            2.6524      0.013    201.967      0.000       2.627       2.678
# court_attorney_type[T.Waived Attorney]                         2.0824      0.014    152.248      0.000       2.056       2.109
# prior_record_points                                           -0.2428      0.002   -127.214      0.000      -0.247      -0.239
# ==============================================================================
# Omnibus:                  2884736.811   Durbin-Watson:                   1.683
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      26274292119.826
# Skew:                         -14.046   Prob(JB):                         0.00
# Kurtosis:                     646.732   Cond. No.                         104.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Regression # 2: **Controlling for the process served, which how defendants learn their charges**
# This could be a source of variation, so should I control for it? (e.g. black people getting targeted arrests)
# lets see...

# %%
# ADDING PROCESS SERVED
m_RANK = smf.ols("case_DELTA_cl ~ race + sex + prior_record_points + court_attorney_type + process_served", regression).fit() # controlling for initial charge gives me the plea bargain 
colors = ['r' if m > 0 else 'g' for m in m_RANK.params]

# plot effects
m_RANK.params.plot(kind='bar', title= "Who gets better plea deals?", figsize=(15,8),color=colors,legend=False, ylabel='Delta Case Offenses Class Rank')  
plt.tight_layout()
plt.savefig('Who_gets_better_deals.png', transparent=True)
m_RANK.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          case_DELTA_cl   R-squared:                       0.118
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                 1.190e+04
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:33:06   Log-Likelihood:            -4.6761e+06
# No. Observations:             1518819   AIC:                         9.352e+06
# Df Residuals:                 1518801   BIC:                         9.352e+06
# Df Model:                          17
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    -14.2434      0.122   -116.427      0.000     -14.483     -14.004
# race[T.Black]                                                 -0.2949      0.063     -4.670      0.000      -0.419      -0.171
# race[T.Hispanic]                                               0.2589      0.064      4.065      0.000       0.134       0.384
# race[T.Other]                                                  0.1752      0.066      2.638      0.008       0.045       0.305
# race[T.White]                                                 -0.1616      0.063     -2.565      0.010      -0.285      -0.038
# sex[T.Male]                                                   -0.0206      0.009     -2.173      0.030      -0.039      -0.002
# sex[T.Other]                                                  -0.1128      0.149     -0.755      0.450      -0.405       0.180
# court_attorney_type[T.Privately Retained Attorney or Self]     0.1956      0.017     11.214      0.000       0.161       0.230
# court_attorney_type[T.Public Defender ($ salaried)]            1.5447      0.014    113.129      0.000       1.518       1.571
# court_attorney_type[T.Waived Attorney]                         1.3479      0.014     98.595      0.000       1.321       1.375
# process_served[T.C]                                           12.9096      0.105    123.262      0.000      12.704      13.115
# process_served[T.I]                                            2.0659      0.497      4.155      0.000       1.091       3.040
# process_served[T.M]                                           11.4701      0.105    109.428      0.000      11.265      11.676
# process_served[T.O]                                            5.9514      0.113     52.703      0.000       5.730       6.173
# process_served[T.S]                                           11.0783      0.108    102.993      0.000      10.868      11.289
# process_served[T.W]                                            9.9055      0.105     94.496      0.000       9.700      10.111
# process_served[T.X]                                           11.9747      0.120     99.870      0.000      11.740      12.210
# prior_record_points                                           -0.1472      0.002    -77.449      0.000      -0.151      -0.144
# ==============================================================================
# Omnibus:                  2906750.755   Durbin-Watson:                   1.722
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      29877989302.760
# Skew:                         -14.250   Prob(JB):                         0.00
# Kurtosis:                     689.522   Cond. No.                         351.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Regression # 3: **Using relative delta instead of absolute**

# %%
# NOW, IF I DO THE RELATIVE CHANGE as my response variable

# Using the Class Rank severity scale
m_RANK = smf.ols("case_DELTA_cl_rel ~ race + sex + prior_record_points + court_attorney_type", regression).fit() # controlling for initial charge gives me the plea bargain 
colors = ['r' if m > 0 else 'g' for m in m_RANK.params]

# plot effects
m_RANK.params.plot(kind='bar', title= "Who gets better plea deals?", figsize=(15,8),color=colors,legend=False, ylabel='Delta Case Offenses Class Rank')  
plt.tight_layout()
plt.savefig('Who_gets_better_deals.png', transparent=True)
m_RANK.summary()
#
#
# ok, when I controlled for process served, it makes black people get better deals than whites. 
# Process served does explain a difference between whites and blacks. 
# It furthers my belief about how white people are getting into the system is different than blacks
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      case_DELTA_cl_rel   R-squared:                       0.175
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                 3.217e+04
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:34:05   Log-Likelihood:            -1.4077e+06
# No. Observations:             1518819   AIC:                         2.815e+06
# Df Residuals:                 1518808   BIC:                         2.816e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     -0.3270      0.007    -43.959      0.000      -0.342      -0.312
# race[T.Black]                                                 -0.0985      0.007    -13.413      0.000      -0.113      -0.084
# race[T.Hispanic]                                               0.1592      0.007     21.508      0.000       0.145       0.174
# race[T.Other]                                                 -0.0541      0.008     -7.008      0.000      -0.069      -0.039
# race[T.White]                                                 -0.0991      0.007    -13.532      0.000      -0.113      -0.085
# sex[T.Male]                                                   -0.0146      0.001    -13.261      0.000      -0.017      -0.012
# sex[T.Other]                                                  -0.5853      0.017    -33.824      0.000      -0.619      -0.551
# court_attorney_type[T.Privately Retained Attorney or Self]     0.0103      0.002      5.088      0.000       0.006       0.014
# court_attorney_type[T.Public Defender ($ salaried)]            0.4762      0.001    319.954      0.000       0.473       0.479
# court_attorney_type[T.Waived Attorney]                         0.1884      0.002    121.526      0.000       0.185       0.191
# prior_record_points                                           -0.0311      0.000   -143.810      0.000      -0.032      -0.031
# ==============================================================================
# Omnibus:                   242628.125   Durbin-Watson:                   1.667
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           391017.828
# Skew:                          -1.101   Prob(JB):                         0.00
# Kurtosis:                       4.155   Cond. No.                         104.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Regression # 4: **Using relative delta instead of absolute**

# %%
# AGAIN, THE RELATIVE CHANGE as my response variable BUT with the min sentence severity scores

# Using the MIN SENTence Rank severity scale
m_RANK = smf.ols("case_DELTA_ms_rel ~ race + sex + prior_record_points + court_attorney_type", regression).fit() # controlling for initial charge gives me the plea bargain 
colors = ['r' if m > 0 else 'g' for m in m_RANK.params]

# plot effects
m_RANK.params.plot(kind='bar', title= "Who gets better plea deals?", figsize=(15,8),color=colors,legend=False, ylabel='Delta Case Offenses Class Rank')  
plt.tight_layout()
plt.savefig('Who_gets_better_deals.png', transparent=True)
m_RANK.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      case_DELTA_ms_rel   R-squared:                       0.117
# Model:                            OLS   Adj. R-squared:                  0.117
# Method:                 Least Squares   F-statistic:                 2.004e+04
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:35:07   Log-Likelihood:            -1.3132e+06
# No. Observations:             1518819   AIC:                         2.626e+06
# Df Residuals:                 1518808   BIC:                         2.627e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     -0.5405      0.007    -77.318      0.000      -0.554      -0.527
# race[T.Black]                                                 -0.1331      0.007    -19.294      0.000      -0.147      -0.120
# race[T.Hispanic]                                               0.0536      0.007      7.710      0.000       0.040       0.067
# race[T.Other]                                                 -0.0061      0.007     -0.846      0.397      -0.020       0.008
# race[T.White]                                                 -0.0693      0.007    -10.068      0.000      -0.083      -0.056
# sex[T.Male]                                                   -0.0029      0.001     -2.811      0.005      -0.005      -0.001
# sex[T.Other]                                                  -0.1766      0.016    -10.862      0.000      -0.209      -0.145
# court_attorney_type[T.Privately Retained Attorney or Self]     0.0017      0.002      0.885      0.376      -0.002       0.005
# court_attorney_type[T.Public Defender ($ salaried)]            0.3998      0.001    285.894      0.000       0.397       0.403
# court_attorney_type[T.Waived Attorney]                         0.2629      0.001    180.530      0.000       0.260       0.266
# prior_record_points                                           -0.0165      0.000    -81.003      0.000      -0.017      -0.016
# ==============================================================================
# Omnibus:                   158647.957   Durbin-Watson:                   1.739
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           214667.776
# Skew:                          -0.920   Prob(JB):                         0.00
# Kurtosis:                       3.098   Cond. No.                         104.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Regression # 5: **Adding COUNTY**

# %%
# ADDING COUNTY
m_RANK = smf.ols("case_DELTA_cl_rel ~ race + sex + prior_record_points + court_attorney_type + key_county_num", regression).fit() # controlling for initial charge gives me the plea bargain 
colors = ['r' if m > 0 else 'g' for m in m_RANK.params]

# plot effects
m_RANK.params.plot(kind='bar', title= "Who gets better plea deals?", figsize=(15,8),color=colors,legend=False, ylabel='Delta Case Offenses Class Rank')  
plt.tight_layout()
plt.savefig('Who_gets_better_deals.png', transparent=True)
m_RANK.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      case_DELTA_cl_rel   R-squared:                       0.187
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     3198.
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):               0.00
# Time:                        17:58:18   Log-Likelihood:            -1.3967e+06
# No. Observations:             1518819   AIC:                         2.794e+06
# Df Residuals:                 1518709   BIC:                         2.795e+06
# Df Model:                         109
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     -0.2907      0.008    -35.770      0.000      -0.307      -0.275
# race[T.Black]                                                 -0.0689      0.007     -9.436      0.000      -0.083      -0.055
# race[T.Hispanic]                                               0.1876      0.007     25.475      0.000       0.173       0.202
# race[T.Other]                                                 -0.0283      0.008     -3.655      0.000      -0.043      -0.013
# race[T.White]                                                 -0.0639      0.007     -8.768      0.000      -0.078      -0.050
# sex[T.Male]                                                   -0.0130      0.001    -11.875      0.000      -0.015      -0.011
# sex[T.Other]                                                  -0.5557      0.017    -32.309      0.000      -0.589      -0.522
# court_attorney_type[T.Privately Retained Attorney or Self]    -0.0224      0.002    -10.221      0.000      -0.027      -0.018
# court_attorney_type[T.Public Defender ($ salaried)]            0.4635      0.002    304.634      0.000       0.460       0.466
# court_attorney_type[T.Waived Attorney]                         0.1763      0.002    111.145      0.000       0.173       0.179
# key_county_num[T.10]                                          -0.0503      0.009     -5.645      0.000      -0.068      -0.033
# key_county_num[T.100]                                          0.0450      0.005      9.240      0.000       0.035       0.055
# key_county_num[T.110]                                         -0.0277      0.006     -4.583      0.000      -0.040      -0.016
# key_county_num[T.120]                                         -0.0153      0.004     -3.506      0.000      -0.024      -0.007
# key_county_num[T.130]                                         -0.1296      0.006    -21.382      0.000      -0.141      -0.118
# key_county_num[T.140]                                          0.0695      0.015      4.542      0.000       0.040       0.099
# key_county_num[T.150]                                         -0.0775      0.006    -12.353      0.000      -0.090      -0.065
# key_county_num[T.160]                                         -0.1182      0.012    -10.218      0.000      -0.141      -0.096
# key_county_num[T.170]                                         -0.0655      0.005    -13.439      0.000      -0.075      -0.056
# key_county_num[T.180]                                         -0.0542      0.007     -7.967      0.000      -0.068      -0.041
# key_county_num[T.190]                                         -0.0917      0.012     -7.909      0.000      -0.114      -0.069
# key_county_num[T.20]                                          -0.0572      0.012     -4.943      0.000      -0.080      -0.035
# key_county_num[T.200]                                         -0.2615      0.015    -17.402      0.000      -0.291      -0.232
# key_county_num[T.210]                                         -0.1274      0.023     -5.591      0.000      -0.172      -0.083
# key_county_num[T.220]                                         -0.0529      0.006     -9.530      0.000      -0.064      -0.042
# key_county_num[T.230]                                         -0.0777      0.007    -11.010      0.000      -0.092      -0.064
# key_county_num[T.240]                                         -0.0386      0.005     -7.429      0.000      -0.049      -0.028
# key_county_num[T.250]                                         -0.0376      0.005     -7.365      0.000      -0.048      -0.028
# key_county_num[T.260]                                         -0.1505      0.010    -14.607      0.000      -0.171      -0.130
# key_county_num[T.270]                                         -0.1273      0.007    -18.667      0.000      -0.141      -0.114
# key_county_num[T.280]                                         -0.1295      0.005    -24.421      0.000      -0.140      -0.119
# key_county_num[T.290]                                         -0.0695      0.009     -7.664      0.000      -0.087      -0.052
# key_county_num[T.30]                                          -0.2222      0.010    -21.169      0.000      -0.243      -0.202
# key_county_num[T.300]                                         -0.0490      0.006     -7.626      0.000      -0.062      -0.036
# key_county_num[T.310]                                         -0.0330      0.005     -6.755      0.000      -0.043      -0.023
# key_county_num[T.320]                                          0.0595      0.007      8.806      0.000       0.046       0.073
# key_county_num[T.330]                                         -0.1230      0.004    -29.013      0.000      -0.131      -0.115
# key_county_num[T.340]                                         -0.0939      0.008    -12.083      0.000      -0.109      -0.079
# key_county_num[T.350]                                         -0.0581      0.005    -11.530      0.000      -0.068      -0.048
# key_county_num[T.360]                                         -0.1923      0.019    -10.302      0.000      -0.229      -0.156
# key_county_num[T.370]                                         -0.1455      0.021     -6.770      0.000      -0.188      -0.103
# key_county_num[T.380]                                         -0.0868      0.008    -10.563      0.000      -0.103      -0.071
# key_county_num[T.390]                                         -0.1595      0.012    -13.239      0.000      -0.183      -0.136
# key_county_num[T.40]                                          -0.1265      0.010    -13.188      0.000      -0.145      -0.108
# key_county_num[T.400]                                         -0.0706      0.004    -16.678      0.000      -0.079      -0.062
# key_county_num[T.410]                                         -0.1870      0.007    -26.011      0.000      -0.201      -0.173
# key_county_num[T.420]                                         -0.1214      0.007    -17.742      0.000      -0.135      -0.108
# key_county_num[T.430]                                         -0.0034      0.007     -0.507      0.612      -0.017       0.010
# key_county_num[T.440]                                         -0.0844      0.006    -14.751      0.000      -0.096      -0.073
# key_county_num[T.450]                                         -0.1807      0.011    -16.789      0.000      -0.202      -0.160
# key_county_num[T.460]                                          0.0032      0.008      0.403      0.687      -0.012       0.019
# key_county_num[T.470]                                         -0.4769      0.019    -25.305      0.000      -0.514      -0.440
# key_county_num[T.480]                                         -0.1256      0.005    -27.231      0.000      -0.135      -0.117
# key_county_num[T.490]                                          0.0158      0.008      1.853      0.064      -0.001       0.032
# key_county_num[T.50]                                           0.0485      0.012      4.197      0.000       0.026       0.071
# key_county_num[T.500]                                         -0.0996      0.005    -18.246      0.000      -0.110      -0.089
# key_county_num[T.510]                                         -0.0201      0.013     -1.546      0.122      -0.046       0.005
# key_county_num[T.520]                                         -0.1026      0.007    -13.880      0.000      -0.117      -0.088
# key_county_num[T.530]                                         -0.1988      0.006    -32.876      0.000      -0.211      -0.187
# key_county_num[T.540]                                         -0.0705      0.006    -10.938      0.000      -0.083      -0.058
# key_county_num[T.550]                                         -0.0253      0.009     -2.832      0.005      -0.043      -0.008
# key_county_num[T.560]                                         -0.0966      0.010     -9.316      0.000      -0.117      -0.076
# key_county_num[T.570]                                         -0.1036      0.009    -11.548      0.000      -0.121      -0.086
# key_county_num[T.580]                                          0.0105      0.006      1.731      0.084      -0.001       0.022
# key_county_num[T.590]                                          0.0991      0.004     24.507      0.000       0.091       0.107
# key_county_num[T.60]                                          -0.2414      0.007    -35.757      0.000      -0.255      -0.228
# key_county_num[T.600]                                         -0.1205      0.013     -9.342      0.000      -0.146      -0.095
# key_county_num[T.610]                                         -0.1562      0.008    -19.664      0.000      -0.172      -0.141
# key_county_num[T.620]                                         -0.0963      0.006    -15.696      0.000      -0.108      -0.084
# key_county_num[T.630]                                          0.0562      0.006      9.737      0.000       0.045       0.068
# key_county_num[T.640]                                         -0.1552      0.005    -32.433      0.000      -0.165      -0.146
# key_county_num[T.650]                                         -0.1902      0.014    -13.813      0.000      -0.217      -0.163
# key_county_num[T.660]                                         -0.1289      0.005    -25.897      0.000      -0.139      -0.119
# key_county_num[T.670]                                          0.1471      0.005     27.139      0.000       0.136       0.158
# key_county_num[T.680]                                         -0.1830      0.013    -13.713      0.000      -0.209      -0.157
# key_county_num[T.690]                                         -0.2295      0.008    -27.054      0.000      -0.246      -0.213
# key_county_num[T.70]                                          -0.1857      0.013    -14.416      0.000      -0.211      -0.160
# key_county_num[T.700]                                         -0.1537      0.008    -18.751      0.000      -0.170      -0.138
# key_county_num[T.710]                                         -0.1501      0.015     -9.984      0.000      -0.180      -0.121
# key_county_num[T.720]                                         -0.0052      0.007     -0.733      0.464      -0.019       0.009
# key_county_num[T.730]                                         -0.0867      0.005    -16.992      0.000      -0.097      -0.077
# key_county_num[T.740]                                         -0.0466      0.010     -4.721      0.000      -0.066      -0.027
# key_county_num[T.750]                                         -0.1587      0.005    -32.078      0.000      -0.168      -0.149
# key_county_num[T.760]                                         -0.1611      0.008    -19.437      0.000      -0.177      -0.145
# key_county_num[T.770]                                         -0.0575      0.005    -11.643      0.000      -0.067      -0.048
# key_county_num[T.780]                                         -0.0630      0.006    -11.289      0.000      -0.074      -0.052
# key_county_num[T.790]                                         -0.0422      0.004     -9.404      0.000      -0.051      -0.033
# key_county_num[T.80]                                          -0.0737      0.008     -9.524      0.000      -0.089      -0.059
# key_county_num[T.800]                                         -0.0615      0.006    -10.686      0.000      -0.073      -0.050
# key_county_num[T.810]                                         -0.0730      0.006    -12.043      0.000      -0.085      -0.061
# key_county_num[T.820]                                          0.0404      0.008      5.163      0.000       0.025       0.056
# key_county_num[T.830]                                         -0.1569      0.007    -21.789      0.000      -0.171      -0.143
# key_county_num[T.840]                                         -0.1337      0.008    -16.405      0.000      -0.150      -0.118
# key_county_num[T.850]                                         -0.0676      0.006    -11.827      0.000      -0.079      -0.056
# key_county_num[T.860]                                         -0.0714      0.013     -5.294      0.000      -0.098      -0.045
# key_county_num[T.870]                                         -0.0125      0.009     -1.377      0.169      -0.030       0.005
# key_county_num[T.880]                                         -0.0343      0.013     -2.604      0.009      -0.060      -0.008
# key_county_num[T.890]                                         -0.1365      0.005    -25.347      0.000      -0.147      -0.126
# key_county_num[T.90]                                          -0.0759      0.006    -12.846      0.000      -0.087      -0.064
# key_county_num[T.900]                                         -0.0785      0.007    -11.281      0.000      -0.092      -0.065
# key_county_num[T.910]                                         -0.0304      0.004     -7.925      0.000      -0.038      -0.023
# key_county_num[T.920]                                         -0.0347      0.012     -2.813      0.005      -0.059      -0.011
# key_county_num[T.930]                                         -0.1045      0.011     -9.676      0.000      -0.126      -0.083
# key_county_num[T.940]                                          0.0416      0.007      5.595      0.000       0.027       0.056
# key_county_num[T.950]                                         -0.0882      0.005    -17.153      0.000      -0.098      -0.078
# key_county_num[T.960]                                         -0.0959      0.006    -16.654      0.000      -0.107      -0.085
# key_county_num[T.970]                                         -0.0063      0.007     -0.956      0.339      -0.019       0.007
# key_county_num[T.980]                                          0.0077      0.007      1.050      0.294      -0.007       0.022
# key_county_num[T.990]                                         -0.0652      0.013     -4.902      0.000      -0.091      -0.039
# prior_record_points                                           -0.0296      0.000   -134.795      0.000      -0.030      -0.029
# ==============================================================================
# Omnibus:                   243043.371   Durbin-Watson:                   1.689
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           393986.113
# Skew:                          -1.097   Prob(JB):                         0.00
# Kurtosis:                       4.188   Cond. No.                         213.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
pd.crosstab(regression.race, regression.process_served)
# Out:
# process_served     B        C    I       M      O       S       W      X
# race
# Asian              6    35797    0    6945    272     557    4138     93
# Black           1787  1602639  479  655815  36512   94095  739427  12495
# Hispanic         141   534851   44   80600   1138    4612   40606   1408
# Other             99   185902   46   42617   6622   19210   59685    623
# White           3615  2153509  732  748038  55667  122489  803232  10813

# %%
regression[['race', 'case_DELTA_ms_rel']].groupby(by='race').mean()
# Out:
#           case_DELTA_ms_rel
# race
# Asian             -0.717344
# Black             -1.285000
# Hispanic          -0.810801
# Other             -1.027934
# White             -1.129005

# %%
regression.race.value_counts(normalize=True)*100
# Out:
# White       48.319363
# Black       38.962567
# Hispanic     8.223264
# Other        3.902195
# Asian        0.592611
# Name: race, dtype: float64

# %%
regression[['race', 'prior_record_points']].groupby(by='race').mean().sort_values('prior_record_points').reset_index()
# Out:
#        race  prior_record_points
# 0  Hispanic             0.263521
# 1     Asian             0.448745
# 2     Other             0.875962
# 3     White             1.505137
# 4     Black             1.785467

# %%
round(pd.crosstab(regression.race, regression.court_attorney_type, normalize='index')*100,2)
# Out:
# court_attorney_type  Appointed ($ hourly)  \
# race
# Asian                                7.84
# Black                               24.62
# Hispanic                             7.06
# Other                               19.18
# White                               25.33
#
# court_attorney_type  Privately Retained Attorney or Self  \
# race
# Asian                                               7.31
# Black                                              18.87
# Hispanic                                            5.21
# Other                                              10.80
# White                                              10.50
#
# court_attorney_type  Public Defender ($ salaried)  Waived Attorney
# race
# Asian                                       67.83            17.03
# Black                                       32.42            24.09
# Hispanic                                    73.36            14.37
# Other                                       49.77            20.25
# White                                       45.32            18.85

# %%
# Boxplots

white = regression[regression["race"] == "White"]['case_DELTA_cl']
black = regression[regression["race"] == "Black"]['case_DELTA_cl']
asian = regression[regression["race"] == "Asian"]['case_DELTA_cl']
hispanic = regression[regression["race"] == "Hispanic"]['case_DELTA_cl']
other = regression[regression["race"] == "Other"]['case_DELTA_cl']

# Visualize petal length distribution for all species
fig, ax = plt.subplots(figsize=(15, 7))

# Remove y-axis tick marks
ax.yaxis.set_ticks_position("none")
# Add major gridlines in the y-axis
ax.grid(color="grey", axis="y", linestyle="-", linewidth=0.25, alpha=0.5)
# Set plot title
ax.set_title("Distribution of ABSOLUTE severity of charges vs convicted by Race")
plt.xlabel("Race")
plt.ylabel("Relative severity of charges vs convicted")
# Set names as labels for the boxplot
dataset = [
    white,
    asian,
    black,
    hispanic,
    other,
]
ax.boxplot(
    dataset,
    labels=[
        "white",
        "asian",
        "black",
        "hispanic",
        "other",
    ],
    showfliers=False,
)
plt.show()

# %%
# Boxplots

white = regression[regression["race"] == "White"]['case_DELTA_cl_rel']
black = regression[regression["race"] == "Black"]['case_DELTA_cl_rel']
asian = regression[regression["race"] == "Asian"]['case_DELTA_cl_rel']
hispanic = regression[regression["race"] == "Hispanic"]['case_DELTA_cl_rel']
other = regression[regression["race"] == "Other"]['case_DELTA_cl_rel']

# Visualize petal length distribution for all species
fig, ax = plt.subplots(figsize=(15, 7))

# Remove y-axis tick marks
ax.yaxis.set_ticks_position("none")
# Add major gridlines in the y-axis
ax.grid(color="grey", axis="y", linestyle="-", linewidth=0.25, alpha=0.5)
# Set plot title
ax.set_title("Distribution of RELATIVE severity of charges vs convicted by Race")
plt.xlabel("Race")
plt.ylabel("Relative severity of charges vs convicted")
# Set names as labels for the boxplot
dataset = [
    white,
    asian,
    black,
    hispanic,
    other,
]
ax.boxplot(
    dataset,
    labels=[
        "white",
        "asian",
        "black",
        "hispanic",
        "other",
    ],
    showfliers=False,
)
plt.show()

# %%
# Boxplots

white = regression[regression["race"] == "White"]['case_DELTA_ms']
black = regression[regression["race"] == "Black"]['case_DELTA_ms']
asian = regression[regression["race"] == "Asian"]['case_DELTA_ms']
hispanic = regression[regression["race"] == "Hispanic"]['case_DELTA_ms']
other = regression[regression["race"] == "Other"]['case_DELTA_ms']

# Visualize petal length distribution for all species
fig, ax = plt.subplots(figsize=(15, 7))

# Remove y-axis tick marks
ax.yaxis.set_ticks_position("none")
# Add major gridlines in the y-axis
ax.grid(color="grey", axis="y", linestyle="-", linewidth=0.25, alpha=0.5)
# Set plot title
ax.set_title("Distribution of ABSOLUTE severity of charges vs convicted by Race")
plt.xlabel("Race")
plt.ylabel("Relative severity of charges vs convicted")
# Set names as labels for the boxplot
dataset = [
    white,
    asian,
    black,
    hispanic,
    other,
]
ax.boxplot(
    dataset,
    labels=[
        "white",
        "asian",
        "black",
        "hispanic",
        "other",
    ],
    showfliers=False,
)
plt.show()

# %%
# Boxplots

white = regression[regression["race"] == "White"]['case_DELTA_ms_rel']
black = regression[regression["race"] == "Black"]['case_DELTA_ms_rel']
asian = regression[regression["race"] == "Asian"]['case_DELTA_ms_rel']
hispanic = regression[regression["race"] == "Hispanic"]['case_DELTA_ms_rel']
other = regression[regression["race"] == "Other"]['case_DELTA_ms_rel']

# Visualize petal length distribution for all species
fig, ax = plt.subplots(figsize=(15, 7))

# Remove y-axis tick marks
ax.yaxis.set_ticks_position("none")
# Add major gridlines in the y-axis
ax.grid(color="grey", axis="y", linestyle="-", linewidth=0.25, alpha=0.5)
# Set plot title
ax.set_title("Distribution of RELATIVE severity of charges vs convicted by Race")
plt.xlabel("Race")
plt.ylabel("Relative severity of charges vs convicted")
# Set names as labels for the boxplot
dataset = [
    white,
    asian,
    black,
    hispanic,
    other,
]
ax.boxplot(
    dataset,
    labels=[
        "white",
        "asian",
        "black",
        "hispanic",
        "other",
    ],
    showfliers=False,
)
plt.show()
# ????????????????????????????????

# %%
# prior record agains race, and scatter of prior record vs deltas

# %%
regression.loc[regression.case_DELTA_ms_rel.isna()]
# Out:
# Empty DataFrame
# Columns: [case_id, CL_Rank, case_DELTA_cl, case_DELTA_ms, case_DELTA_cl_perc, case_DELTA_ms_perc, case_DELTA_cl_rel, case_DELTA_ms_rel, key_county_num, key_year, race, sex, court_attorney_type, process_served, prior_record_points, plea_code, def_zip_address, usps_zip_pref_city, year, COUNTY, total]
# Index: []

# %% [markdown]
# # by COUNTY / DISTRICT COURT

# %%
# Panel OLS - relative drop in MIN SENTENCE RANK
# regression_multiindex = regression.set_index(['key_county_num', 'key_year'])


# from linearmodels import PanelOLS
# mod = PanelOLS.from_formula('case_DELTA_ms_rel ~ 1 + race + sex + prior_record_points + court_attorney_type + TimeEffects + EntityEffects',
#                             data=regression_multiindex)
# mod.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)

# %%
# Panel OLS - relative drop in CLASS RANK

# from linearmodels import PanelOLS
# mod = PanelOLS.from_formula('case_DELTA_cl_rel ~ 1 + race + sex + prior_record_points + court_attorney_type + TimeEffects + EntityEffects',
#                             data=regression_multiindex)
# mod.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
